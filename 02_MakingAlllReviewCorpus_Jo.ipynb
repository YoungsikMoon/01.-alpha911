# %%
import pandas as pd

review_data = pd.read_csv('/content/boom_final.csv') #결측치 제거된 데이터 업로드 후 읽음 "봄툰csv 디렉터리의 dr"
review_data.head() #불러온 데이터 빠르게 확인

print('데이터 개수: {}'.format(len(review_data)))

# 문자열 아닌 데이터 모두 제거
review_data = [review for review in review_data['댓글'] if type(review) is str]
review_data.to_excel('AllReviewCorpus.xlsx', index=False)
review_data.to_csv('AllReviewCorpus.csv', index=False)

review_data.to_excel('파일명.xlsx', index=False)
review_data.to_csv('파일명.csv', index=False)
# Out:
# 데이터 개수: 73335
# <ipython-input-5-c3fa66352476>:3: DtypeWarning: Columns (3,4,5,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   review_data = pd.read_csv('/content/boom_final.csv') #결측치 제거된 데이터 업로드 후 읽음
# ['아니.... 상상도 못한 방법으로 회피하셔가지고 저도 놀랐어요... ',
#  '아무리 생각해도 어릴적에 너무나도 매력적인 남성과의 접촉이,,,, 그의 성적 취형을 결정짓게 만든것이 아닐까 합니다,,,, ',
#  '하...계란야무지게얹은미니토스트아이팟케이스쓰는공어때,',
#  '그럼 아저씨가 평생 책임져요',
#  '정말 죄송한데 딱 한번만 실수로 벽에 끼이셨으면..!',
#  '뽀갈하고 이마깨지기ㅋㅋㅋㅋㅋ큐ㅠㅠ',
#  '문성이 가슴에 있는 햄버거 먹으면 되겠네',
#  '작가님 전 좋은 독자가 될게요',
#  '와 과거의 옆집 아저씨가 지금은 자신을 선생님이라고 부르고 있다니 미쳤다...♡',
#  '아기공 동정따먹고 감옥가도 할말없다는 연상수 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ',
#  '가슴이 시끄럽네요',
#  '너는 무슨 같이 싸우겠다는 말을 빤스만 입고 하니',
#  '진심 미칠거같아ㅠㅠㅠㅠㅠㅠ 총 안맞을 수 있는데 공 차에 안타서 맞은거임?퓨ㅠ',
#  '수 허벅지랑 공 허리가 비슷하다? 진짜 눈물이 입가에서 흐른다',
#  '내 거대 날다람쥐야….',
#  '저런 엄한 몸매로 밥을 해주다니..\n결혼이죠 이건.. ',
#  '술 약한 아기공 집에 데려다 줘 떨어지는 라면 봉지 잡아 줘 근데 연하의 키스는 피하는...문성씨 죄가 많네ㅎㅎ',
#  '저렇게. 멀끔하고.\n가슴을 내미는데.\n고.백을.어떻게.거 절합니까..? 여우수가 분..명합니다.',
#  '와시 허리들어간거봐 옷 너무 바람직하다',
#  '아니 미친 문성씨 시계 찬거 왜 이렇게 꼴림? 진짜 쌉. 댄디. 쌉떡대. 쌉 간지남 깔리는 것 같은 느낌을 배로 주는 것 같아서 미치겠음',
#  '잠깐 좀 먼곳에 가있었다는 게 과거였던걸까요?\n미인공 떡대미남수 좋아요ㅜ',
#  '수도 은근 자각없이 플러팅하는거같은데 ㅋㅋㅋㅋㅋ 아무리 의구심때문에 신체적 접촉을 한거긴 하지만,,, ㅋㅋㅋㅋㅋㅋㅋ 호감도 없이 글케 스킨쉽을,,,?!?! ',
#  '호연이 빡친 얼굴 너무 치명적이라 명치가 아프다',
#  '가슴이 너무 시끄러워요......',
#  '진짜 이런 말 참아야 하는거 알지만 그.... 벽고 한 번만 좀....',
#  '아니   ㅋ  ㅋㅋ  ㄱㅋㄱㅋㅋㅋㅋㅋㄱㅋㅋㅋㅋ 우리 애 마빡 우짜노!!!! ㅠㅠㅠ ㅋㅋㅋㅋ',
#  '아자씨 넘 귀여워요',
#  '문성씨 코트 안에 그렇게 입고 활동하시는 거예요? 감사합니다,,,,,,,',
#  '육체미 난리났다',
#  '침대 구깃한거보고 왜 얼굴 붉히냐고!!!!\n저 새파랗게 어린것한테 동했다고 왜 말을 못해!!!!!!!!!!!!!!!',
#  '공 나이 묻고 혼자 헉 해서 횡설수설하는 거 넘 기여워 아기야...ㅋㅋㅋㅋㅋ',
#  '아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ뽀뽀 댓가가 너무 큰거 아닌지 ㅠㅠㅋㅋㅋㅋㅋ',
#  '뭐뭐야 시간을 거스르는 자야 뭐야',
#  '나는 가슴 큰미남이 저도 모르게 연하의 마음을 흔들어 놓는것에 약하다',
#  '키작미인공 너무 좋아요ㅜㅜㅜ',
#  '떡대수에 이끌려왔어요^^',
#  '미쳤다 최고로 아름다운 키작공쇼...',
#  '저몸매를 보고 못알아보긴 어렵지... 너무 섹시한 청소부 아닌가요? ',
#  '가슴에 안전벨트 낀거봐',
#  '키작공 붐은 온다... 덩치차이 미쳤다이',
#  '호연이가 나이 좀 어리고 키가 좀 작지 이제 어른이다 곷추도 다 컸고,, 보여줘 호연아',
#  'ㅠㅠ 이미 빤쮸 개봉하셔서 환불 불가능하세요',
#  '키작 연하공...진짜 귀하다....수 뒤에 서있으면 완벽하게 안보여....\n잘들어요컷에... 진짜 덩치차 미친듯',
#  '문성 씨 아기공 유기하면 안 됩니다',
#  '나 브라 왜차고 다니냐.',
#  '빤스만 입고 말해서 그런지 귀엽당.... ',
#  '서브공으로 활약하다가 연하공한테 깔릴 상일세 ',
#  '와....진짜 하나도 안벗었는데 개야하다',
#  '이모티콘 쓰는거 모르는거임.....?개모에하다...',
#  '이건 잘하면 죽겠는데 ㅋㅋㅋㅋㅋㅋㅋ',
#  '여친아니야!!!!!남친이야!!!!!',
#  '태석씨 아직 잘 모르겠지만 누군가에게 깔렸음 좋겠어요 맛있어보여요',
#  '키작미인연하공이랑 왕가떡대미남수... 완벽한 조합.. 작가님 당신은 키작공계의 천사.. 에인졀....',
#  '어넓골좁 미남떡대수의 표본으로 적당합니다 그래서 이제부터 제꺼입니다',
#  '문성씨 섹시다이나마이트셔요 의상이 세상에',
#  '체격차 진짜 뽕차네요 너무 좋다ㅠㅠ 그나저나 투과능력은 몸 안에 있는 타인의 체액도 투과시킬 수 있을까요? 그럼 참 편할??텐데ㅎ...',
#  '요즘 유행 한품공.... 크으',
#  '9화만에 공이 죽을수도 있나요..?',
#  '호연아 젊고 탱탱한 건 한정판이야 너는 지금 한정판이라고 희소성으로 이겨야해 알겠어???',
#  '자길 두려워하게 된다고 해도 공을 위해서 다 죽인다고!?!?!?!?!?!띠바 이건사랑임.',
#  '역키잡 가보자고',
#  '돌아왔구나 나의 가슴',
#  '다음주에 떠있을 19금 딱지에 흥분.중',
#  '기생오라비...남자한테 최고의 칭찬...',
#  '니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어? 니 왜 그렇게 웃어?',
#  '아기공의 반란이 시작된다',
#  '둘이 다른 스타일로 예쁜거 미치겠어요 선 곱고 섬세한쪽이 공이고 선 굵고 깔끔한쪽이 수라니.... 문성씨는 벅차겠지만 난 벅차올라',
#  '아니 호연이 진짜 눈 저렇게 뜨는데 누가 안반함...',
#  '애기 둘러메고 가는 으른수 개멋있어ㅠㅠㅜㅜㅜ',
#  '저게 가슴이야 햄버거야....',
#  '진짜..............................이렇게 제 취향 스트라이크 작품이 나오다니..........................................\n내통장 다 가져가주세요 작가님..................................................................................................',
#  '공 허벅지가 수 허벅지 반쪽임 ',
#  '진짜 작화 특색있고 극락임 너무 좋다',
#  '약간의 후회수 시작인가요???하지만 가슴때문에 면죄드리겠습니다',
#  '호연이 개씹미인이고 문성씨 개씹미남이라 너무 행복함 심지어 개씹미인이 개씹미남 따먹을 예정^-^-^-^-^',
#  '아주 엎치락뒤치락 서로 주도하려는 모습들이 보기좋네요^^',
#  '와 짹쨱..컷에 등빨 개미쳤어....역시 남자는 등.. 아니.. 가슴...등ㅇ..아니 가슴으로 말한다.',
#  '아저씨가 매우 귀엽고 눈치가 조금 없구 가섬이 맛있었요.',
#  '할 수 있습니다',
#  '아기 호연이 너무 귀엽다ㅜ몸만 크고 얼굴은 지금이랑 크게 다른 게 없다는 점까지 존맛도리',
#  '진짜 없어서 못 먹는 천상의 맛이예요.\n얘네가 나중에..... 한다고? 이 생각만 하면 어떤 장면을 봐도 자극적입니다.',
#  '아기가 화나면 건물을 뿌셔...',
#  '동정 와기공의 순수하고 길티 느껴지는 질문과 커여운 남친선언.....  이건 미쳤다고밖에..... 문성씨 길티플레져와 진짜쾌감 동시에 느끼시니 어떠신지요.... 이게 연하와기공의 참맛...?! 둘의 체격차이마저 감상포인트라 이번화 눈 바빳습니다.... 텍스트 음미하랴 작화 음미하랴....',
#  '호연이 이,, 공녀석,,, 꼴에 공이라고 지금 막 걱정하고 나서고 그러는데,,,!!! 아무리 네가 문성씨 (꿈에서) 깐다고 정말 전투적으로 강한것도 아닌데~!!!! 모하는거냐고 지그으음!!!! \n답답하게 자꾸 문성씨 맞게 틈을 만들고!!!! 네가 나서야할때는 침대위지 이럴때가 아니야!!!!! ',
#  '오늘 엄청난 떡밥이 나온 것 같은데 가슴만 생각남..혹시 문성 씨 초능력은 단체 세뇌인가요?',
#  '합격!!합격입니다 모르겠고 그냥 무조건 합격이에요',
#  '수 뒤에 숨겨지는 공...정말 귀하다...',
#  '진짜 감격스러운 가슴이다…..',
#  '아 저돌적인 이 애기를 어쩌냐..',
#  '호연이 눈에 눈물 고인 거 봐 니가 바로 한 떨기의 장미다...☆',
#  '문성씨 팔뚝만 나와도 야함',
#  '미친 키가 다 고추로 간거냐? 진짜 너무좋다. 덩치차이랑허ㅏㅁㄴ어ㅣㅏㅓ마ㅣㄴ이ㅓㅏ',
#  '안돼 문성씨 땅파지마 땅파지마!!!!!!!!!!!!!!! 이쁜 호연이의 쬐끄마한 품에서 아니다 너무 작으니까 문성씨 이메다 품에서 이쁨 호연이 끌어안고 행복하기만 해!!!!!!!',
#  '이렇개 섹시해놓고 홀라당 자버리시면 어뜩해요 아저씨',
#  '좋아...란 말 한마디에 연하공 눈깔 돌아버립니다',
#  '문성씨 젊은 애인이 이렇게 좋은 거에요',
#  '아 진짜 가슴땜에 다 까먹음',
#  '아니 한병에 만취를 했어? …심지어 남았어? ㅋㅋㅋㅋㅋㅋㅋ아 난 술 약한 공이 좋더라',
#  '아. 이 큐티연하공이 드디어 일을 친다. 작가님!!!!!!!!! ',
#  '헐 진짜 잠깐 먼곳이었다는게 사실 과거로 갔던건가? ??? 문성씨가 생각이상으로 너무 핫가이라 ... 바지 실루엣만 봐도 제가 다 두근거리네요,,,',
#  '떡대수컷연상수 가슴으로 촉감놀이하는 한품연하공 실존',
#  '그정도 가슴이면 초능력말고도 여러가지로 발동되겠다 ',
#  '무ㅜ야? 신혼부부야 뭐야?? 작가님은 좀더 오래걸릴거라고했지만 다음날 같은침대에서 일어나는거 아니냐???',
#  '아니 떡대수 미인공만도 감지덕지인데 거기에 역키잡이요...? 작가님 진짜 ㅠㅠㅠ 사랑해요',
#  '저새끼가 감히 우리 미인공 얼굴에 손을 대?\n저 턱수염 다뜯어버릴것',
#  '아니 태석씨 저렇게 쫙 빼입고 나와서 문성이가? 이러네 고자극이다 진짜ㅠㅠㅜㅜ',
#  '안돼용 환불ㄴㄴ 반품ㄴㄴ',
#  '와... 네가 어렸으니까 이거랑 가슴밖에 생각 안 남...',
#  '문성씨 아기 홀리지마세요.',
#  '으른들 보다가 호연이 보니 진짜 아기 그 잡채...문성 씨는 진짜 몇 살인 거예요',
#  '그의 정체 너의 남편',
#  '애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁...... 애 생기는 것도 아니고... 드르륵.. 탁......',
#  '연하공 직진!!!!!! 채고다 진짜….',
#  '호연아 미안.. 난 이 남자도 괜찮은거같다',
#  '가슴은 장난아닌데 허리는 한줌(?)........개맛있다 \n글고 덩치땜에 수가 공같아 보이는거 ....진짜 조..아....',
#  '근육이너무흥분됨......아진짜너무좋음아진짜키작공은하늘이내린선물임아진짜좋다진짜너무행복하다',
#  '문성씨 자꾸 가슴에 시선 뺏기게 하지마세요 제가 이런다고 가슴에만 신경쓰여서 대사를 못볼 것가슴나요?',
#  '훗..이제 알았나 아기고양이...?',
#  '헐레벌떡 남편 간수 하러 온 아기공.. 귀엽다.. ',
#  '이봐요 직원씨 같이 놀라자고',
#  '아니 우리 아가공 어디로 사라진!??!!?! 문성씨....이제 후회수의 길만 남앗군요,,',
#  '연하 아기랑 붙어먹었음 책임져야한다구요',
#  '어우씨 연하미인키작공 최고다',
#  '태석씨.. 아저씨.. 당신 왜케 맛 좋게 생겼나요',
#  '문성은 문성 씨, 태석이는 아저씨...\n호연이 넘 기특해...',
#  '덩치차 그림체차 최상이에요 요몇달 본 미인공떡대수 비엘 중에 감히 최고임',
#  '문성씨 겉코트 안에 옷을 입은 거야 뭐야 저렇게 야하게 입고 다녔다니..',
#  '공 맞을까바 자기가 맞은거봐 시히히히발 가섬이 뛴다',
#  '문성씨 현대 문물이랑 낯가리는 거 같은데 데이트 많이 하자...',
#  '제목의 &#039;창&#039;이 창문을 뜻하는 줄 알았는데 무기인  &#039;창&#039;을 뜻하는 걸까요??아님 이중적 의미인 걸까요 수가 생긴 것만큼 강수 그 자체라 너무 좋아요 게다가 미남이라 더 짜릿해요 하아..',
#  '너...유죄야......',
#  '둘이 덩치차이 흐뭇하다 귀한 키작공,,,',
#  '문성씨는 &#039;진짜&#039; 남자입니다.\n사유: 진짜 남자는 가슴으로 이야기함. ',
#  '나 벌써,, 문성씨 분수쇼 보고싶어,,여름이니까,,작가님,,알잘딱깔센? 부탁드려요.',
#  '어유... 가섬이 푸짐하네요.....그 와중에 라면 왜이렇게 맛깔나게 잘 그리신건쥐..츄베릅 ',
#  '헉 키작공 미인공 떡대수 미남수,........ 작가님 사랑합니다',
#  '아이고 ㅠㅠ 어어머니랑 마주친적 있어서 피한듯 ㅠㅠ 문성쿤 안늙고 그대로니까...어머니가 보면 어케 생각하겠으 ㅠㅠ',
#  '문성씨 오늘 몸매 200점인데..... 오드리문성의 낯가림..',
#  '왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어 왜 움찔했어',
#  '요기 댓글창만 오면 키작공 대 메이저임,,, 님들 사랑해요,,, 님들 대체 어디 숨어있다 나타난거에요,,,',
#  'ㅇㄴ 애기 이마를 깨버리면 어떡해요 \n\n이 아저씨 규탄한다 \n가슴과 사랑으로 보상하라\n아기에게 이것저것 보장하라\n독자에게 누드에이프런을 제공하라',
#  'ㅠ진지한 분위기인데 문성씌 핫바디밖에 안보이는 나... 떡대수에 홀려버린 나...',
#  '근데 레알로모르는데....',
#  '덩치차 진짜 너무 만족스러워요.. ',
#  '눈물흘리면서 왜 그랬냐고 묻는 문성씨 어떻게 가만둬!!!!!!!!!!!!! 호연아!!!!!!!!!!! 어서 위로!!!!!!!!!! ',
#  '당신. 중년 수?',
#  '저돌적인아기에 문성이가 밀리는 모습..아름답다',
#  '아니. 식빵같은 가슴을 가진 님을 좋아해요...ㅠㅠ',
#  '왓다 내 삶의 축복',
#  '하 문성씨 북슬북슬 머리에 치였다',
#  '오빠가 왜 거기서 나와?',
#  '아니... 문성씨 너무 핫바디라 얇은천으로는 가려지지도 않네.. 와중에 호연이 열받은 얼굴 치와와네요',
#  '당연하지 며느리인데',
#  '말라가는 떡대수 작품속 한줄기 오아시스세요 선생님....',
#  '어후…허벅지차이 진짜 개변태같고 좋다 증말…',
#  '탈랜틐ㅋㅋㅋㅋㅋㅋㅋ저희 어머니가 쓰시는 단어인뎈ㅋㅋㅋㅋㅋㅋㅋㅋ문성찌ㅋㅋㅋㅋㅋㅋㅋㅋ그나저나 애덜 장가가자마자 시즌1 완결이라니 넘나 아쉽디만....! 더 성장해서 올 우리 와기공을 열심히 기다려보겠습미다 작가님!',
#  '죽음으로..능력각성한건가여..',
#  '표정 안좋은거 인생이 힘들어서 ㅋㅋㅋㅋㅋㅋㅋ',
#  '캬... 아기고양이공과 듬직미남수 조합 최고야..',
#  '아기공 길거리 유기 이거 불법이에요 문성씨',
#  '말랑. ',
#  '아....입이 귀에걸려서 잇몸 말라가는데\n입꼬리가 안내려온다....ㅎㅎㅎㅎㅎㅎ\n문성씨 적극적인 모습 너무 좋거 맛있...멋있다',
#  '문성이 얼굴 감상하는 거 봐ㅋㅋㅋㅋㅋ 역시 연하미인공은 미모와 나이로 승부봐야..ㅋㅋㅋ',
#  '키 차이 미쳤나고ㅋㅋㅋㅋㅋ 어우 바람직해',
#  '헐 수는 바로 눈치깠네',
#  '감사합니다 작가님 만수무강하시어요',
#  '키스 조르는 아기공 너무 소중해요',
#  '호연아 문성이 잘 느낀다 매운맛을 보여주자 ',
#  '시작하자마자 가슴으로 꼬시는 연상남 어때 난 꼬셔졌어',
#  '울 연하공 2시간 동안 사과 문자 고민한 거 넘 귀엽고 짠해ㅠㅠ 절망하지마ㅏㅜㅜㅠㅠ',
#  '에어팟을 버리다니… 케이스만 버린거겠져…작가님…?',
#  '한번 친절하게 대해줬을뿐????? 딱걸렸다 이제 그것때문에 당신 남은 생을 전부 이 아기연하공에게 바치게될것이다 ',
#  '지금까지 스토리상 태석씨 능력인 것 같아요 하지만 놀랍다 브레인역할 일반인인 줄 알았는데',
#  '그치 여친은 아니지\n듬직하고 귀여운 남친이 있지',
#  '문성씨 아기연하공에게 감기고 있는 것 같아서 조음..',
#  '하오츠',
#  '저렇게 바라보면 그냥 무장해제 되는 거지 호연아 너는 얼굴이 무기다',
#  '썸네일 진짜 꼴리네요',
#  '으악!!!!! 애 마빡 우짜누ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 책임지고 결혼해',
#  '문성이 귀걸이 고자극 미쳤음 ',
#  '그래 둘이 이제 결혼하자',
#  '불안해...왜지? 너무 불안해....',
#  '아니 머야 문성씨 설마 지금 애인 아니라고 했다고 나이 차이 나는 것 같다고 삐진거야?!!!!!!!!!!!!!!!!!!! 미친거아냐 꺄하핳 원래 뭐라고 댓글 달려고 했었는진 기억도안나네 호연아 임마!! 그런 말을 왜 해가지구!!! 얼른 문성씨 달래줘라!! ',
#  '아 흉부가 기가막혀 흉부가 기가막혀',
#  '와 덩치 차이는 엄청 나는데 거..기 크기는 절대 안 밀리네ㅋㅋㅋㅋ',
#  '작은공 힘내랏....!',
#  '우리 이쁜 공 눈에 빗물과 눈물이 찰랑거리는 연출이 끝내주네요.. 으윽ㅠㅠㅠㅠ 그다음도 감동이지만..',
#  '문성 씨 가슴이 너무 말랑가슴 하신 거 아닌가슴',
#  '기다렸어요!!! 문성의 보름달만한 가슴을!!!!',
#  '마참내.. 다음주 기대할게요',
#  '난닝구가 잘 어울리는 남성 맛있다...',
#  '엌ㅋㅋ 여자 같은 수는 썸넬만 보고 거르는데 오늘따라 이끌려 들어왔더니 미인공이었군요 떡대수 킬러는 흐뭇합니다',
#  '감자네컷... 굿즈로 주시면 좋겠다 정말 너무 갖고 싶음 내 손에 저게 없다는 게 말이 안 돼...',
#  '오드리 문성을 갖는 건 역시 쉬운 일이 아니군요...오히려 좋아. ',
#  '세상이 낯선가봐ㅠㅠㅠ',
#  '너 꼬실려고',
#  'ㅋㅋㅋㅋㅋ너무당돌한 아기공ㅋㅋㅋㅋㅋㅋ',
#  'ㄹㅇ 개맛도리 하아 작가님 떡대수 사랑하는 사람은 여기 눕습니다',
#  '문성씨 황소가 투우사해도 되는건가요',
#  '넓고 포근한 가슴',
#  '누구신데 중요한 말을 자르세요....저 궁금해서 미치겠어요.......ㅠㅠ흐흑 이노무 사건들아 둘이 있을 시간을 좀 줘라 줘',
#  '및친 막컷 덩치 차이 너무 좋아 존맛',
#  '아기공에게 닥친 시련ㅋㅋ질투해라',
#  '흉부가 기가 막혀',
#  '세울까요 진짜 발칙하고 앙큼하다... 호연이 요녀석... 아주 남친 맘 흔들어제끼네...',
#  '문성씨 가슴은 어디까지 커지는걸까...',
#  '하 이 맛에 키작공 떡대수를 보는 거구나.... 딜리샤스',
#  '오늘도 맨몸에 시계만 걸친 문성씨는 고자극',
#  '강아지 힘내 응원한다!',
#  '누가 나 기절시켰다 10월에 깨워줘…',
#  '진짜 인생수 나타났다 하 ㅠㅠㅠㅠㅠㅠ',
#  '문성씨 저희 다 봤어요 호연이가 끼잉거릴 때마다 홍조 띄우시는 거 다 봤다구요 이미 강아디한테 감긴 거 다 티나니까 땅 파지 말고 호연이랑 백년해로 하라구요 이 잘생긴 근육 감자야!!!!',
#  '아기고양이 한껏 꾸몄구먼 ㅋㅋ',
#  '아 진지한 상황에 이래도 되는건지 모르겠는데 너무 맛있게 생기셨어요',
#  '아 호연이 ㅠㅠㅠㅠㅠ 문성씨 앞에서는 순한 포메더니\n갑자기 화가난 치와와됐네ㅋㅋㅋㅋㅋㅋㅋ',
#  '초면에 실례지만 깔려주세요.',
#  '아 미친 개맛있다 아 너무 맛있어요 후루룹 짭짭',
#  '호연이 허리 돌리는거 미쳤',
#  '한품에 들어오는 키작공 완전 좋네요 어우 완전 좋탕 ㅎㅎㅎㅎㅎ아하하!!!!.. 여기 누울래요 ...',
#  '개같이 기다렸습니다 오드리 문번',
#  '정말 이 작품을 볼때마다 느끼는건데 이번편이야말로 작가님의 연출,실력이 진짜 엄청나다는걸 다시 한번 느꼈습니다.인체 표현은 말할것도 없고...어떻게 이렇게 액션씬까지 잘 표현하시는건지..걍 천재같습니다',
#  '후욱후욱 손크기차이 화못참아서 능력컨트롤못하고 수상쳐입어서 멘붕온 공 달래는 연상수..진짜최고다',
#  'ㅅㅅ할 때 저러면 웃기겠닼ㅋㅋㅋㅋㅋㅋㅋ 박는 것도 아니고  안 박는 것도 아니고',
#  '마지막 토스트케이스땜에 내용 다 까먹음ㅋㅋ',
#  'read님 벽고ㅋㅋㅋㅋ 배우신 분',
#  '자 눈치 챘으면 이제 저 두사람을 위해 자리좀 비켜주자',
#  '문성씨 검은옷 진짜…..개미침……후….',
#  '우리 강아지 빨리 구하러 와요,,,\n거짓말같이 썸남 등장',
#  '하 술취해서 고분고분 다 대답하고 저런 눈으로 쳐다보는게 어케 참아요 애기는 참지 않아!!!!!!!',
#  '설호연 27세 첫사랑에게 키스갈기려다 개같이 임종',
#  '아 ㅠㅋㅋㅋㅋㅋ 에어팟인가 귀엽잖아',
#  '아이고 저런 우리 공이 비맞은 강아지가 됐네ㅠㅠㅠ 아들 돌봐준 사람이라 알아봤겄지..',
#  '놀러 (데이트) 가자는데 등산로? 이러는 연상 ㅠㅋㅋㅋㅋㅋ',
#  '작가님 부디...은퇴하시기까지 떡대수 많이 그려주세요😭',
#  '신.음공 최고다..',
#  '좋은 남자친구가 되겠다고 다짐하는 아기. 넘 킹랑스러운거 아니냐구요오오오',
#  '작화 퀄리티 무슨 일이야 끝없는 미모들의 향연에 눈이 개안하는 중',
#  '트럭에 들어가는 거 킹멋있다..',
#  '댓글창이 너무 제 머릿속 같고 난잡해요',
#  '회피형인 나에게 개탐나는 초능력',
#  '연하공 너무 귀엽잖아 진짜 아악',
#  '진짜 이정도로 내 취향에 꼭 들어맞는 키작공 떡대수 첨이야..감사해요 문성씨 젊은 애인 축하해요',
#  'ㅆㅂ 링피어싱 미쳤나 존나따이고싶어????????',
#  '헐 몰랐는데 눈여겨보지 않아 몰랐는데 귓불이 잘려있었네요 피어싱 얘기가 괜히 나온게 아니었군요',
#  '문성씨누가함부로연하애인놀리고피식웃고가슴크고허리얇고상남자같으면서박히고야하게신음흘리면서느끼래요벌로평생애기연하랑지지고볶고살아',
#  '오드리햅번이라니.. 작가님이 의도하신대로 요즘보기드문 청순성숙고전미남 그대로였답니다... 그 아우리가 어디서나오나 햇더니 모티브가.. 가슴이벅차올라요',
#  '내가 따까리였으면 무기검사 전에 휘파람 불어서 혼났을 것이다...',
#  '아니 고작 그걸로 후회수라뇨? 왕가슴한테 너무 하시네요 ㅠ ㅠ \n미인공 납치된듯 ',
#  '합격.',
#  '않이 작가님 전작은 꿈에서 글케 진탕하더니,,,\n이번작도 꿈에서 이러고 아침짹이라니 ㅠㅠㅠㅠㅠ',
#  '미쳤다 역키잡',
#  '옆에서 같이 싸우겠다는 연하공 기특해요 기특해요',
#  '저 남자랑도 분위기 묘하네..',
#  '행복한 새해 ',
#  '초능력을 이런 식으로 쓸 줄은.. 호연씨 문성씨가 듣고 있어 대답 잘하렴!!!!ㅠ',
#  '오늘 호연이 너무 갱쥐 그자체...♡ ',
#  '....? 다음주가 시즌1 최종화라니요.......',
#  '초면에 기생오래비 소리 듣는 거 보니 굉장히 미인이구나',
#  '우리 강아지한테 무슨짓이야아아아악!!!!!!!!!!!!!!!!!!!!!!!!',
#  '태석씨 갖고 싶다..',
#  '미인공 떡대수 진짜 좋다...ㅜㅜ',
#  '아니 저 선생님 저얼굴인데 쓰레기라고? 누가 나타나서 대신 굴려줘',
#  '키작공이면 키워드를 붙여달라구요 작가님~!!! 예고만 보고 놓칠 뻔 했잖아요ㅜㅜㅜ',
#  '들이박아',
#  '직진 연하공 이길 다정 연상수 읎다',
#  '공 너무 작고 귀여워어어어',
#  '아니다 문성이가 다 커도 된다 \n내 눈에 호연이 꺼츄가 더 커보이는 것 같은데 \n그깟 꺼츄 작아도 상관없다 \n이 얼마나 귀하디 귀한 장면인가 \n키작연하공은 맵다...',
#  '작가님이 문성씨 가슴에 진심이라 행복해요 정말',
#  '귀여운 에어팟 케이스 쓰는 공.. 귀하다.,,',
#  '수가 시간여행 가능한가... 멀리 갔었다는게 과거로 시간여행? 그나저나 공보다 큰 떡대수라 정말 넘 좋습니다. 그간 떡대수라고 하고는 공보다 수가 작아 눈물 흘리며 봤는데 증말 넘 행복합니다. 미인키작공과 미남떡대수 너무 아름다운 커플링입니다. 키작공 흥해라ㅠㅠ',
#  '아니 문성씨 낯선 세상에 힘들어하는 거 짠한데 와중에 어깨가 태평양',
#  '와 진짜 안 좋은 게 없네요 하 ㅠㅜ\n1. 떡대수와 한품공\n2. 동정.\n3. 그걸 보고 감옥에 가도 할 말 없다고 죄책감 느끼는 연상수\n4. 화룡점정 "좋은 남자친구가 될게요."하는 조신순정공;;;;;;;;;',
#  '한품에 쏙 들어오는 공.... 극락이다',
#  '하... 저 얼굴로 요즘 애들은 이러는거 진짜 미쳤다..',
#  '오늘도 문성씨는 가슴이 한바가지네... 아저씨 가슴에서 떡대수의 넉넉한 인정과 여유를 느끼며 갑니다...',
#  '문성씨 잃어버려서 우는 강아띠...',
#  '문성이 좀 가만히 냅둬라',
#  '오늘도 문성씨 가슴이 시끄러워요',
#  '아니 미친 문성씨 너무야해요 이게 옷이야 월남쌈이야 ',
#  '가슴이랑 엉덩이 동시에 보여주는 포즈...!',
#  '저 사이즈 병원복이 존재하다니♡ 언제봐도 바람직한 덩치 ',
#  '문성씨너무멋있어ㅜㅜ아ㅜㅜ',
#  '작가님이 둘은 썸을 오래탈 예정이라 침대고고는 늦을 것 같다네요~~',
#  '떡대수 키작공 취향저격이에요. 감사합니다 작가님 ',
#  '음 미슐랭',
#  '와C 오늘자 ㄹㅇ 레전드ㅠㅠㅠㅠㅠㅠ 와아아아악 눈물젖은 아기미인의 제가 당신을 사랑하니까요 발언부터 현관 키스신까지 진짜 미친거아닌가여ㅠㅠㅠㅠㅠㅠㅠ  문성씨 주먹쥐고 벽짚고 있고, 호연이는 문성씨한테 매달려서 올망올망 키스하는거 진짜 미친 레전드 작가님 진짜 꼴잘알 맛잘알 하 미치겠어요 진짜 잇몸이 마르도록 활짝 웃으면서 봄 ㅠㅠ 하 작가님 사랑해여',
#  '하 볼때마다 느끼는건데 문성씨 시계 너무 꼴포예요 쿨톤이신지 맨몸에 실버 시계가 기가막히게 잘 어울리시네...',
#  '우리 와기공 화났다 흐어엉 귀여우어...!!!!!',
#  '태석도 분명 초능력자일텐데\n능력이 뭘까 계속 궁금해왔는데 위장 능력이었구나\n보고한 적도 없다고 했고\n사장을 부른 사람이 없단 건 진짜 사장은 모른단 거니, 구하러 온 것 같은데.\n아이고 이럴 줄 알았다 야 니가 여기서 자빠져 있을 때가 아니다 우리 같이 복수해야지\n이거 아닌가',
#  '그래서 호연아 안 세울 거야…? 나 기다리고 있는데…….',
#  '자고로 떡대수 남편이라면 절륜해야지! 암!\n\n거유문성씨가 울정도로 박아줘야 좋은남친이지!\n\n다음화시즌1종료면 분명 작가님 쉬고오실듯\n다들 미리 마음의준비를...',
#  '문성아 허리잘록한게 내 음심을 자극하는구나..\n자낮 거유남은 존맛이지\n우리 문성이 거유프린세스인데 왕자라뇨ㅠㅠ 악당님 정정해주세요',
#  '식빵케이스 굿즈 내주세요',
#  '안돼 아기공 ㅜㅜㅜㅜㅜ 포기하지마ㅠㅠㅠㅠㅠ',
#  '어떨결에 문성이도 속마음을 말했는데 호감이군 근데 일부러 안피한걸까?아니면 호연이 능력이 너무 우수해서 못피한건가 궁금하네 ㅋ 초능력은 미인공이 더 강했으면 재밌겠닿ㅎ',
#  '좋대… 연하공이 좋다잖아…! 연허 미인공이 당신이 좋대!!!!!!',
#  '호연이 개빡쳣자나요 문성 아조씨,, 본능 따라 가세요 그냥 ',
#  '문성씨 정말 두툼하신 게... 너무 좋네요',
#  '저렇게 큰 가슴에 끼었는데 반응 안하는게 이상하지!!!!!',
#  '공이 진짜 와기햄찌 그자체ㅋㅋㅋㅋㅋ 한입에 넣고 호로록해야함ㅠ',
#  '뭐야 안돼 더 자. 빨리 다시 누워. ',
#  '담부턴 애기 다칠까봐 안피하겠네 ^^',
#  '작가님.,. 자꾸 문성씨 가슴이 저한테 말걸어요.....♥ 너무 행복하네요 감사합니다......♥',
#  '연하공 최고..아조씨 저리가요',
#  '왜.. 왜 문성씨만 두고 가시나요ㅠㅠ',
#  '아 저런 말 들으면 보통 감동적인데 마냥 귀엽게만 느껴지면 어쩌지... 그리고 문성 씨 진짜 너무 섹시해서 그냥 가만히 보기만 했는데도 코피 날 것 같애',
#  '진짜 이런 유죄아저씨는 첨 본다 그래서 마지막은 왜 그러는건데..!!!!',
#  '한 화 한 화 너무 쫄깃하고 심장 뛰어서 좋아요....호연이는 문성이에 비해 너무 아기같고... 그래서 너무 행복해요 ...하 완전 애기공 그 잡채',
#  '공수 키차이 너무 바람직해서 눈물찔끔났어요 키작공의붐은온다',
#  '호연샘 왜 솔의 눈 꼽주세요',
#  '문성씨 정말 크다',
#  '연하공의 안절부절',
#  '건드리지마세욧 아기꺼에요!!! 잘생기면 단가요?! ',
#  '아기공 눈깔 돌아갈 말 골라서 다 하시네요',
#  '작가님 작화 업그레이드 무슨 일..? 오늘도 가슴 문성씨는 가슴 듬직하고 가슴 호연이도 아기 정말 아기 귀엽구나 작가님 시즌2 잘부탁드립니다!!!!! 꺄아악 돌아왔다 나의 월요일 도파민 ',
#  '호연이와 문성씨 미모를 보며 올 상반기 버틸수있었습니다!.!\n초능력물 진짜 좋아하는데 벨웹툰에서 거의 본적도 없는데 이렇게 아름다운 그림체로!!! 이렇게 잔잔하고 벅차는!!!  유령의 창 볼수있어서 넘 즐거웠습니다 ㅠㅠㅠㅜ시즌1 수고 많으셨어요 매주 넘 행복했습니다…푹쉬다 오세요♡♡ ( 문성이의 묘한 미모가 어디서 기인하나 했는데 모티브가 오드리 햅번이었군요..ㅎㅎㅎ 진짜 닮았어요)',
#  '이번 화 읽고 시집 반려 처리 됐습니다 감사합니다',
#  '마침내....',
#  '아기공을 버리는 것은 중죄입니다 몸으로 갚으세요',
#  '호연이 으른 정장핏에 치인다ᆢ',
#  '연하공 따먹고 버리는 수 유우우우우죄',
#  '수 덩치에 가려져서 안 보이는 키작공의 참맛',
#  '아기고양이 털 세우는거 너무 귀여워',
#  '문성이가슴떼어먹자 ԅ(≖‿≖ԅ)',
#  '발현되고나서 신체 나이를 안먹는건가?? ',
#  '애기공 작정했네ㅋㅋㅋㅋㅋㅋ',
#  '하....너무 짜중나ㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '설마... 다음주도.....?\n아아...... 너무...너무 설레요 아....',
#  '저도 좆아요 문성씨',
#  '호연이 너무 미인이어서 놀람',
#  '와씨 호연이 마지막 미쳤습니까 빤스 찢음',
#  '와 중간에 몸 뒤집는데 없는꼬추 터질뻔함..\n자극 오바야',
#  '덩치큰 떡대수.... 그리고 자연근육이 잘 잡힌 키작공..... 퍼펙트....',
#  '이게 대체 무슨 가슴인가요 문성씨  가슴이 대사치고 있어요 작가님 이러시면 제가슴 가슴밖가슴에 안보일가슴나요?',
#  '호연아. 지금이 너의 기회다. 보여줘 너의 연하미. (대충 땡깡부리라는 뜻)',
#  '그림체 진짜 개성있고 너무 좋음 ㅜㅜㅜ',
#  '둘이 먼가 운명의 짝인가 본뒤,, 닿으면 뭐가 더욱 일어나는것 같은뒈~~~ ',
#  '수 나이가 몇이야 너무좋다.. 중년인가요? 더좋아,,♡',
#  '와 호연이가 이렇게 심리적으로 흔들리는 모습… 가슴은 우는데 입은 웃는중',
#  '아 아니 문성씨 그 능력을 이런 곳에 쓰시면 아기가 당황해요',
#  '글애 이사님 마음 있을거 같긴 했어',
#  '이리 와… 하는 연상떡대수에게… 개큰사랑을 느낌…… ',
#  '허벅지 차이도 치이지만\n문성씨의 넓고 큰 가슴 볼때마다 음흉하게\n웃고있는 날 발견한다....호연아 부럽다',
#  '엄마 오늘 내 세계가 바뀌었어\n알몸시계란것은 엄청나구나 왓어바이올런스비주얼\n이렇게 엄청나게아름다운 그림으로 이렇게 완벽한 태평양덩치수라니\n꿈인가요\n아니겠죠\n사랑해요',
#  '안돼!!!!!!!!!!!!!!!!!!후라이 케이스두고 어디간거야 ',
#  '허억 토스트 왜 거기 버려져있어 마음 아프게ㅠㅠㅜㅜ',
#  '옆통차이 진짜 도라버려요 ',
#  '몸두께 차이 ㄹㅈㄷ ㅜㅜㅜㅜㅜ 맛잇어서 눈물난다 ',
#  '역시 연하공은 미모가 최고의 무기',
#  '와씨 가슴 뭐야?',
#  '존나 간지;',
#  '운석니임..! 진짜 운석님 믿고 아묻따 전체결제',
#  '아니 지금 저 숨못쉬겠음 자꾸 문성이가 나 꼬심',
#  '다음 주에 슬프고 야한 내용이란 뜻인 거 아닌가요 ㅠㅠ\n아 문성씌 우리 아기공 속 썩이지 마세요 ㅠㅠ',
#  '베리어면 우리 쪼꼬미가 문성씨를 보호할 수 있는 역할을 할 수 있겠구만',
#  '글고보니 어젯밤에 n번 더 했으면서 또 세울까요 라니 어떤 의미로 놀랍고 대단하네.. ',
#  '썸넬 가슴보고 함박웃음 지으면서 들어왔어요',
#  '우리 아기 초능력이 대단한가보다.. 문성씨랑 상성 잘 맞았으면..! ',
#  '시즌2.. 기다림. \n내 일요일밤의 유흥이.....작가님 빨리 돌아오셔야해요',
#  '진짜 눈물이 난다 \n최근 본 키작공 떡대수 (생각해보니 희귀해서 최근 본 적도 없음) 중에서 진짜 최고입니다.\n사실 그거 말고도 그냥 최근 본 비엘 씬 중에 제일 좋네요. 진짜 야하고 그냥 박문성 뭘 해도, 뭔 말을 해도 야하네요......;;;\n박문성 유죄성 발언도 진짜....... (애가 생기는... 성교육... &#039;선생님&#039;... 젊은 애인...)\n또 호연이가 날씬한 게 너무 야함 ㅠㅠㅠ \n그림 혼신을 다 하신 게 보여서 또 감동....\n그냥 최고네요',
#  '우리 떡대수 문성씨가 두터워서 호연이가 쥐기도 어려워보여요 꺅♡',
#  '와 제목 그대로 유령의 창 등장 \n근데 유령이 너무 핫바디',
#  '문성씌  살이 보이는게 아닌데 이렇게 섹시하다니ㅠㅜㅠㅜㅠ 어후',
#  '판판X풍만..진짜 아름답도다...너무감동이라 눈물날거같아요 ',
#  '형에게서 흑막의 냄시가...',
#  '문성씨너무멋있어.....너무재밋어요 작가님 진짜 잘그리시네요ㅠㅠㅠ',
#  '한품공과 그런 공 지켜주는 딱똑꽉 진짜 좋네요 ㅜㅜ',
#  '떡대수들은 공들 한번씩 깨치는듯 귀영워',
#  '슬프고 야한 씬 맞자나... 근데 생각보다 더 슬프네.... ㅠㅠ  ',
#  '분명 달달하네.... 하고 입 찢어지고 있었는디..',
#  '난 문성씨가... 남자가 향수..?! 이런거나 에어팟을 어색해한다거나 이런 아재같은 면모를 보일때마다 불끈!! 하게된다........',
#  '문성씨 옷이 터질거 같....\n터져도 좋을텐데....',
#  '44화만에 첫데이트하는 우리 애들 제법이네요 ',
#  '형이 왜 거기서 나와?',
#  '밤새 몇번을 해도 좋아하는 사람의 동의만 있으면 바로 세울 수 있는 젊음 체력 그리고 탤런트같은 얼굴봐서 한번만 봐주자 문성씨..!',
#  '그대 가슴에~ 얼굴을 묻고~~',
#  '문성씨 가슴 좀만 작았으면 이미 키스하고도 남았겠다',
#  '다들 아기공이라고 하시는 거 귀여워요....털푸덕 누워있는 컷 넘 속상해보이고 귀엽고ㅠㅠ',
#  '하..미인공 떡대수\n크허어어ㅓ어얶흐걱...헉헉끄읍...쓰으으읍콜록콜록켁허억허억흐어....하....하아...하아아아....쓰콜록콜록켁우에에에ㅔㅇ엑켁으악꺅흐아아아악씁하허억',
#  '메인공 아닌 아저씨는 빠져 (공어매 mind)',
#  '동거 시작',
#  '왜 애기 이마를 깨고 그래요 ㅠㅠㅠㅠ',
#  '문성씨 양손에 애기 머리가 쏙 들어가버려 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '무슨 향일까?🥺🥺',
#  '새해 복 많이 받으세요 작가님!!!',
#  '호연씨랑 문성씨 다른 느낌으로 예쁘네요...\n연하미인공 연상떡대수 너무너무 좋아요...^_^b',
#  'ㅁㅊ.....문성씨가스스로윗옷벗을때부터 숨참으면서봄 ',
#  '왔다 내 키작공 떡대미남수 바이블',
#  '오셨군요\n드디어 월요일이 개쓰레기요일에서 유있날로 신분상승 ',
#  '저렇게 깜찍한 밴드를 코에 붙이고 있는 직진연하공 어케 거절함...',
#  '문성아 니는 코트 필수다. 내 앞에서는 벗도록 .',
#  '음식점도 아닌데 왜 자꾸 보면서 맛있다.,소리가 절로 나올까요?ㅎ,,',
#  '19 보고 춤추며 들어왔네요',
#  '문성씨는 바보 곰탱이야 호연이가 자면서 자기를 상대로 변태같은 꿈 꾸는 줄도 몰라 존나 따먹어 ~~~!',
#  '아저씨 현대적 미남페이스인데 현대문물 모르는 거 너무 귀여워요...',
#  '옆집 아저씨\n옆집 아저씨\n옆집 아저씨\n옆집 아저씨래 작가님 진짜 맛잘알이십니다 쌍따봉드립니다',
#  '아 미틴 개맛있어 미쳤다',
#  '아 흉부가 기가막혀',
#  '가슴최고야',
#  '그럼요 선생님 수업 킵고잉...',
#  '덩치차이 너무 아름다워요',
#  '아앜 귀여워 둘 다 너무 귀여워요 나만 죽어남 ',
#  '앙큼한 호연이 너네 참 귀엽다',
#  '눈치챘는데 뭐하고 있어 어서 병실 나가',
#  '귓불 잘린거 나만 좋은걸까 ...',
#  '호연아 얼른 구하러 와!!!!',
#  '이렇게 완벽한 취향의 웹툰은 처음... 작가님 진짜 사랑해요..... 아아.. 끝내준다 진짜.. ',
#  '오늘따라 넘넘 짧게 느껴졌어요. 아까워서 선 하나하나 더 봤어요. ㅠㅠㅠㅠㅠㅠ',
#  '그래 호연아 너가 아기남친최고의애인좋은동료남자남편 다하자 할수있어 우리 갓기야... 문성씨 독점해버려~! ',
#  '왕고추 미인공 ',
#  'ㅋㅋㅋㅋㅋ 콰장창 부끄러워서 창문 깨부시고 나가는 상상 개웃김 ㅋㅋㅋ',
#  '일주일이 영겁의 시간이다',
#  '아니 저 얼굴에 때릴곳이 어딧다고 저럼? 어이없네 ㅡㅡ  그나저나 문성씨 대체 과거에 뭘하고 지금은 어케된거임 ㅠㅠㅠ ',
#  '와 나란히 앉았을때 어깨랑 팔뚝차이\n 보이시나요?.. 이게 나라다..',
#  '나도 팝콘',
#  '연하공의 참맛 . . ',
#  '너무 재밌고 문성씨가 잘생겼어요',
#  '아니 그렇게 피한다고?ㅋㅋㅋㅋㅋ',
#  '개마쉿네 공이 아방해서 더맛잇어여..;;',
#  '대박의냄새를맡았습니다 ..',
#  '밀치니까 한방에 나가 떨어지는 아기공,,,, ㄱㅇㅇ',
#  '문성씨 애기 평생 책임지시길...',
#  '마지막의 하트 필텈ㅋㅋㅋㅋㅋㅋㅋ 갑자기 분위기가 핑크빛이라니..!!!엌ㅋㅋㅋㅋ 과연 로맨스릴러의 정석이네요!!',
#  '굿즈라니 바로 개처럼 뛰어가!',
#  '죽어있을게요 시즌2 나오면 깨워주세요...',
#  '최고다 이건 아 진짜 와 정말 눈물이 저절로 냐오는 귀한 삼산 댙은 웹툰이다 정말 아 너무 감동적이에툐 와',
#  '워매.... 문성씨 벗었는데 안벗었네??',
#  '저런 옷을 입고 있었다고요....? 세상에 감사합니다',
#  '울아기 얼굴 절대지켜ㅠㅠ',
#  '있던 애기가 없어지니까 집이 적막하게 느껴지는 문성씨... 빨리 집나간 아기공 찾으러 가요 ㅠㅠㅠㅠㅠ ',
#  '호연이 침대에 엎어진다음 일어나면 0ㅇ0모양으로 눈물자국 남을듯...',
#  '아 진짜 빠꾸없는 고백공격 이게 연하의 매력이지... 와중에 호연이 꿈의 문성씨 지나치게 섹시하네요',
#  '우리 호연이 아직 애기라 문성씨 가슴을 더 빨아야하는데...',
#  '다음주까지 500번봐야지',
#  '그아아악....갸아아아아아아악.........크아아아악........크으으윽....으으윽...너무좋아요',
#  '다음주 휴재라니...다음주 월요일을 이제 어케 버티지 ',
#  '라면 먹다 뽀뽀했으면 좋겠다',
#  '독잇 감자. 최고. 최고의 남친. ',
#  '한국 사람을 미치게 하는 법 말하다가 끊기,,,, 전화인 14화 초반을 보면 태석 형이랑 수정 씨, 그리고 문성 씨의 과거가 살짝 나오는데 이 때 수정 씨는 크게 다친 것 같고 아마 문성 태석과는 다르게 운명을 달리 한 것 같네요.. 아마 이 사건이 지금 문성이와 태석이를 다른 길로 만들게 된 큰 계기이지 않을까..그런데 태석이도 문성이를 계속 지켜보는 것으로 보아 아주 손을 뗀 것 같지는 않고 시간이 지날수록 위험에 빠지는 문성이를 막으려는 같긴 한데.. (아직까지는). 과거 나름 또래로 보였던 문성이와 태석이의 외형이 현재인 지금 태석이가 더 나이들어보이는 것으로 보아 문성이가 시간을 건넌 것이 아닌 시간이 멈춘 것으로 보이긴 하는데,,,, 아직은 더 많은 떡밥이 남았을테니 천천히 달려보겠습니다 히히 그나저나 태석이 보다가 호연이 보니 진짜 애기네요 근데 애기 맞음 호연이는 혼자 아는 것도 없을테고 매번 문성이 나오는 야한 꿈에 눈 앞에서 신경쓰이는 상대가 다치기나 하고,, 애기 외로와요,,애기 살려',
#  '아조씨 좀만 더 이따가 오세요ㅠㅠㅠ',
#  '떨어지지 않고 있다가 정분나고 그러는거지 뭐',
#  '콩알눈 문성씨 귀여워',
#  '와 진짜 이런 말은 안 하려고 했는데 꼴린다...',
#  '다음화에 저 노란 머리가 전기 충격기에 지지지직 하는 표정 보고 싶다..',
#  '미친 개멋있네',
#  '와 스토리 진짜 탄탄해요 미쳤다',
#  '음~마싯다',
#  '가슴얘기하러 들어왓다니 이미 가슴얘기만 하는 댓글들',
#  '미친....몸이...너무쌔끈해',
#  '와 손 크기 차이',
#  '떡대수 태그 발견하자마자 이거다 외치고 들어왔어요 캐디가 환상적이네요 맛있게 잘 보겠습니다 념~~~!!!',
#  '그렇게 큰가... 아니아니 잘생긴 얼굴로 애기한테 밥해주면 결혼해야되요 ㅠㅠㅠ 결혼안해주면 연하공법 위반으로 잡혀간대요 문성씨 ㅠㅠ',
#  '아저씨?\n하.... 고자극',
#  '문성씨 두툼해서 너무 좋아요...하...애기공이 최고다...',
#  '여러분 숨쉬세요!!!',
#  '전에도 ㄴㅇㄱ 하는 방법으로 피하시더니 이번에도..\n그런데 우리 얘 넘 놀해요 ㅠㅠ',
#  '오늘 달달함 모야',
#  '문성씨 인별도 모르겠지… \U0001f979 ',
#  '삼각관계 환영합니다 나는 이 관계 찬성일세',
#  '왜 문성씨만 혼자 남겨두는 거죠 ',
#  '운석 작가님 정말 예쁘게 야한 포인트를 잘 아심…애들 둘 다 넘 예뻐요ㅠㅠ',
#  '으아\n문성씨 시발 멋져 사랑스러워',
#  '지져스......떡대미남연상수가....키작미인처연공을 도발하네....멋지다 야~~~',
#  '문성이 허벅지 개미쳤어요 작가님 진짜로',
#  '어우야....진짜...허버지 굵기차이 치인다....죽인다...추릅',
#  '문성씨 그 옷차림 범죄예ㅛ요',
#  '집에 왔는데 강아지같은 애인이 잠옷있고있어 너무기야워........ ',
#  '작가님 진짜 진짜 사랑해요 작가님이 키작미인공을 해주셔서 너무 기쁘고 행복해요 항상 건강하시구 돈도 많이 많이 버세요',
#  '하..‘탈랜트’처럼생겻대.... 어휘봐... 완벽하게 예스러운 아저씨라 너무너무 침나와요 운석님 당신은 저의 달란트입니다..\n',
#  '떡대수 키작와기공의 참맛이 바로 여기 있도다...!!',
#  '광선검 표현조차도 없는데 이렇게 대. 꼴인 작품 처음입니다… 정말 배우신 자까님… 사룽해요 미인공 연하공 키작공 떡대수 연상수 미남수의 보배… 앟 떡대수 진쯯 마싯땋,,,  ◠ ̫◠ ',
#  '다음주까지 숨참고 기다릴게요 ',
#  '미인연하가 너무 예뻐요 미남떡대연상이 너무 잘생겼고 떡대수라 그림에 탕탕 박아주신 거 너무 행복해요 진짜',
#  '그 얼굴로 피어싱 한쪽귀에만 하는거 완전 불법입니다 오늘부터 정해졌어요',
#  '아 맛있다 그냥 서있기만 해도 응..',
#  '힘내.. 원래 연상수의 지나간 세월에 질투밖에 할 수 없는 게 연하공의 참맛이지..~',
#  '작가님 왈: 조만간 호문 진짜 뭔가를 보여드리겠습니다  환상의 키작공쑈 \n저 벌써부터 기다려요 작가님....',
#  '세상에 동거하고 장 보고 뭔데 이 부부같은 분위기...',
#  '호연아 견뎌 미남을 얻는건 원래 희생이 따르는 법이야!!',
#  '미인연하 키작공X연상떡대감자수너무너무귀하고... 그리고 작가님이 기본기탄탄하게 그림을 너무 잘그리셔서 몰입감 maxㅠ... 너무너무좋아요',
#  '문성이 몸 통과하는게 더 편할텐데 공 때문에 칼 쳐낸거 아님?! 개좋타...',
#  '정말 참하다 이 남자',
#  '죽고싶어 너무 예뻐 수... ㅠㅠㅠㅠㅠㅠ 너무너무 사랑스럽고 야해 ',
#  '가슴크기봐...',
#  '공수 덩치차이 너무좋아요.. ♡',
#  '벌써 재밌다아아아아앙아아아아아앙 귀하고 귀한 미인연하공에 유죄연상미남떡대수?!',
#  '암튼 둘이 이미 만난적이 있다는게 완전 천생연분에 점지된 운명이란점이 넘 좋네요,, ',
#  '덕분에 이번주도 살아갈 원동력을 얻었읍니다…문성씨는 진짜 호연이를 사랑할 수 밖에 없을 것 같아요',
#  '현관에서의 장면들 영상처럼 이어지는 거 너무 좋다.. 그리고 문성씨 큰 덩치에 비해 쬐깐한 줫곡주의가 귀여워요',
#  '아 문성씨,,,,,,,,, 와기 애인은 펠라도 울면서 해..., . ......, ......., (짱.)',
#  '와 문성씨 힙한 패션도 어울리고 목걸이도 너무 찰떡 아님 ㅋㅋㅋㅋㅋㅋㅋ 유(령의)창 티셔츠 저도 봄!!!!! 아오 씐난닼ㅋㅋㅋㅋㅋㅋ',
#  '앞으로도 하나하나 더더 기뻐하면서 알아가는일이 많길~^^',
#  '호연이의 죄 너무 멋있는 죄...\n문성씨 겁내지마 멋진 아기남친이 많이 알려준대 ㅠㅠ',
#  '햅번하고 데이트하는 데 향수는 기본이지.. 햐 반짝반짝하니 문성씨도 설레나봉가 나까지 설레는 게 문제지만 ㅎㅎ',
#  '우리 아기공 화났다',
#  '꺄아악 납치?!?! 가보자고오~~~!\n자까님 새해복마니받으시구 건강하세여~!!!',
#  '뽀송한 얼굴에 그렇지  못한 몽둥이',
#  '한품아기공 위에 올라타는 떡대왕가문성씨 너무 고자극 ',
#  '미친... 나 이제 시집 못 가',
#  '진짜 입틀막하고 봄... 개 좋 아 문성 씨 ㄹㅇ 고자극미친다',
#  '이리와 하는 문성씨 진짜 완전 유죄유죄유죄유죄수...',
#  '작가님그림너무아름다워서미치겟어요 문성씨육체미폭발...,..,',
#  "이렇게 맛있는 웹툰을 왜 최근에 알았을까.. 천상의 맛, 극상의 맛, 키작공떡대수의 맛 let's go",
#  '아기공........ 소듕해......',
#  '호연이 밥 야무지게 차려준 것 봐 ... 완전 1등 신랑감',
#  '뭐야 뭔데 왜 같이 봐!!',
#  '고전미남ㅠㅜㅠㅠㅜㅠ 진짜 옛날흑백사진속에서 나올법한 그런첫사랑같은 이미지의 문성씨... 그래서 아기호연이의 잊지못한 첫사랑이 된거겟쥬ㅠㅜㅠ 하너무좋네요.. 귀한 tmi뜯어먹으면서 시즌2 기다리겠습니다 작가님 사랑합미다...♡♡♡',
#  '작가님이 평생 연재해주시면 좋겠어요 ㅈㅂㅈㅂ...',
#  '아 너무 야한데 귀여워 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우리 와기공 때릴데가 오디있다고ㅠㅠㅠㅠ',
#  '문성씨 아기공 찾으러 갑시다,,,',
#  '아니 근데 문성씨 흉통이 정말 훌륭하시네요 옆모습이 아주 워후',
#  '이번 화 너무 귀엽네요 .......... 작가님 너무 좋아요 ',
#  '열시만 기다렷어요 쟉가님 ',
#  '총 맞은 자리에 흉터가 이렇게 꼴릴 일인가..?',
#  '아진짜 너무 좋아요... 작가님 만수무강 대성하세요...',
#  '한품에',
#  '불로의 피...',
#  '월요일이 기다려지는 유일한 이유',
#  '문성씌 몸매랑 호연이 얼굴 볼때마다 힐링된다.. 떡대수 미인공 좋아요..',
#  '가슴에 감동 먹었습니다',
#  '아니 알람도 안울렸는데 왜 일어나 임마!!',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 호연이와 문성이의 첫뽀뽀의 맛은 바닥맛인가요... 이건 뽀갈이 아니라 이마가 빠갈난게 아닌지',
#  '남자는 가섬으로 말한다',
#  '하씨 문성씨 너무 잘생겼어요 가슴까지 갓벽…',
#  '계란토스트 아이팟???? 하찮고 귀엽네',
#  '분명 총알 관통 장면인데 왜 너른 가슴팍에 자꾸만 눈이 가네요....',
#  '유죄수.. 가슴부터 뚫고 나오네 진짜 대박맛있다',
#  '둘이 너무 케미가....오지네요',
#  '연상수?떡대수? 와마 나 흥분대자냐',
#  '작가님 작화 진짜 개쩌시네요 ㅠㅠ',
#  '하...너무야해요ㅠ\n별거안했는데 야해요ㅠㅠ',
#  '박력있게 벽쿵키스 갈기는 문성씨 이건 유죄입니다',
#  '한품미인공 딱똑콱떡대수 조합 어케 안 사랑함',
#  '가슴에 끼인 펜던트가 되고 싶다..',
#  '미쳤다 아기 눈물에 리미트 해제 된 문성씨 ',
#  '헿ㅎ나두 님들만 봐두 배불러여ㅎㅎㅎ',
#  '문성씨 티셔츠에 유창 ㅋㅋㅋㅋ',
#  '무자각 얼빠 ㅋㅋㅋㅋㅋㅋㅋㅋ 천생연분이다',
#  '문성 씨 진짜... 지켜주고 싶은 매력도 있음. 이러니까 애기가 자꾸 지켜주려고 하지 ㅋㅋㅋ',
#  '"말랑"',
#  '퍼즐조각 완성!',
#  '네 그러니 자리 비켜줍시다',
#  '호연이한테 진짜 미안한데...태석문성 단 한번만 보고싶다...',
#  '씩씩한 아기공이 나가신다',
#  '호연이 유독 애기같네 이번편ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '태석아저씨 능력이 이거였구나 ㄷㄷ..',
#  '미 미미 미쳤다 인형 너무 예뻐요',
#  '어이쿠 마지막의 빛나는 스탠드와 크리스마스 이브에 외롭지 말라고 오로라를 퐉퐉 뿜어주시는 인형 덕분에 앞 내용을 까먹었네요ㅎㅎ  .. 아맞다 호연이 없으니 나까지 불안해지네 문성씨 ..',
#  '호여나 그냥 세우기나 해ㅜㅠㅜ',
#  '문성씨 허벅지….츄베릅',
#  '여친이 아니긴 하지...!',
#  '나는 키작미인공을 그냥 좋아하는게 아니라\n진짜 ㅈ나게 좋아했던거구나... 입꼬리가 안내려가요 작가님 하...ㅋ ㅋㄱㄱ ㅋ ㅋㅋㅋ',
#  '문성씨 장가는 다 갔다 이제',
#  '미쳣다',
#  '아니 오늘 문성씨 왤케 잘해주죠? 이렇게 잘해줄라고 그렇게 화냈나? 맨날맨날 화내줘 그리고 맨낳맨날 잘해줘~~~ 으어어 박력미인감자수유죄연상형아 최고~~~~~',
#  '최고의 맛집',
#  '문성씨 농염한 것 봐 ... 이게 연상의 맛?!',
#  '없어서못먹는 연하미인키작공…너무 귀해요 작가님 감사합니다 감사합니다…',
#  '아미쳣다진짜조흠',
#  '미인공떡대수존맛탱구리',
#  '화해 ㅅㅅ가자',
#  '여전히..곱네..그..가슴..',
#  '오셨다 오셨다!!!',
#  '기다리고있엇어요~~~~~ 사랑해요작가님..',
#  '매번 문성씨랑 호연이 눈이랑 눈썹 진짜 특색있게 공들이셨다 생각했는데 역시ㅠㅠ전투복도 진짜 섹시해요ㅠㅠ덕분에 이런 모든 부분이 다 취향에 들어맞는! 연하키작미인공연상떡대미남수 작품을 만날 수 있게 되어서 정말 너무너무 감사할 따름입니다..다음 시즌에 어시님 축전처럼 달달하게 데이트하는 둘도 볼 수 있으려나욬ㅋㅋ작가님 화이팅! 10월에 봬요!!',
#  '역시 후기는 캐릭터 탄생 오리진이나 비화를 알 수 있다는 점에서 짱인듯... 그리고 저도 누가 10월에 깨워주세요,, 작가님 진짜 재밋게 봤어요ㅠㅠㅠㅠ 즌2까지 건강하게 지내시고 꼭 돌아와주세요 열심히 돈 벌고 있을게요ㅠㅠㅠㅠ(대충 뒷주머니에 사진 넣고 포대 짊어지고 가는짤',
#  '지치고 힘들 때 꼭 봐야하는 만화 1위',
#  '문성씨 너무 이뻐 말안되',
#  '하 설레는 덩치차이 너무 맛잇고요 그저 극락 천상의 맛 사랑해요',
#  '어머니가너무미인이세요',
#  '하 호연이 겉으론 딱딱한 척 하면서 독백은 냥냥 거리면서 하루종일 문성 아저씨 생각만 하는 거 너무 귀엽다 진짜 이 애기를 어떡하면 좋니',
#  '이번주 스킵 안되나요 다음주 월요일이 급해요',
#  '나도 문성씨 만져보고싶어요..... 악당 부하놈들만 만지고.... 호연이도 만지게해줘!!!! ',
#  '오우예',
#  '문성씨 불로불사구나.. 그래서 함께 못한다고 하는거구나 ㅜ ㅜ ㅜ ㅜ',
#  '화해색수해',
#  '문성씨 옆으로 사라지는 거 왜케 웃김 ㅋㅋㅋㅋㅋ',
#  '와 근데 문성씨 진짜 핫바디네',
#  '아기연하공이 할 법한 말만 하는 호연이......',
#  '작가님 근육표현 미쳣어요......',
#  '앞으로 대화는 무조건 얼굴을 맞대고가 아닌 거시기를 맞대고\n참고하겠습니다 감사합니다',
#  '이 분은 또 누구야\n얼굴의 축복이 끝이없네 끝이없어..',
#  '형수님 지금 방해 하실 때가 아닌데 ',
#  '하 작가님 진짜\n키작공 떡대수의 정석까지 완벽하게 구현하셨는데\n중년까지 너무 잘 그리셔서 눈물나요 너무 감사합니다 ㅡㅜ',
#  '하 개멋있다',
#  '떡대 미남의 매력은 왕가슴 뿐이 아니로군요. 역시 등짝도 중요... 작가님 오늘도 감사합니다ㅠㅠ',
#  '아아 썸넬보고 수가 나쁜일이라도 당한 줄 알고 기대햤잖아요',
#  '처맞는 떡대수????!?!!??!?!! ',
#  '아기 이마 깨졌더',
#  '당황해서 능력쓴건가!?ㅋㅋ아이고 이마..!!ㅋㅋ',
#  '숨참고봤네',
#  '가슴때문에 아무것도 안보이는데 이게 맞나요',
#  '보니까 시간여행능력자가 아니고 나이를 안 먹는거같은데\n솔의눈같은 아재취향 그득한 음식들만 봐도',
#  '그럼 나이 차이가..?',
#  '내가 조아하는 키워드 총집합이다!!\n아저씨수 떡대수 강수 연상수 왕가수♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡\n작가님 만수무강하세요!!!',
#  '이럴수가 존나 취향인 작품이 나와버렸다',
#  '아 미친 둘이 너무 찰떡이다 작가님 사랑해요',
#  '흑흑 그림체도 너무 예쁘고 떡대도 너무 예쁘고 공도 예쁩니다.. 전개 시원시원한 것 같아서 더 좋아요',
#  '개미쳤다',
#  '갑사합니다 갑사합니다 착하게살겠습니다',
#  '역대급 고자극씬...',
#  '썸네일 문성씨 가슴이 너무 시끄러워서 허겁지겁 들어왔어요',
#  '저 오늘 호연문성과 똑같은 딸기크로플을 먹었어요,,, 비쥬얼이 아예 똑같아요,,,, 나 애들이랑 함께하고 있어,,,ㅠ',
#  '달콤하다..',
#  '그래 얘들아 그렇게 사랑하면서 살걸아',
#  '문성씨 가슴팍이랑 어깨봐…',
#  '등산로 피톤치드보다 100배 나은 향기',
#  '아저씨가 뭔데나가라마라에요 !\n겁나 통쾌하다 \n늙은이는 빠져!!!!!',
#  '오늘 특히 호연이 작화 진짜 예쁘네요! 잘보고 있습니다 작가님 ㅎㅎ ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 역시 팀브레인이어서 제일 먼저 눈치 깠네',
#  '커플 사이에 깨달음을 얻고...',
#  '문성씨 행복에 젖어<<라는 말이 꿈에서 나오는 걸 보니 호연과의 관계에서 행복에 젖어가고 있었구나 그 점에서 문성이 원하는 걸 떠나서 아주 복수 공동체로서 붙잡아 놓으려는 태석씨가 쎄해요 얘는 문성이 불행하게 만들 거야 쎄한 놈!!',
#  '아아 답답하다 호연씨 빨리 와 너이 그이 쓰러졌듸 ㅠㅠ',
#  '작가님 새해복많이받으세요😻😻',
#  '끼에에엑 15일까지 어떻게 기다려 ',
#  '세워서 사죄해라',
#  '체력좋은것봐...공답다 ',
#  '출판사야 피디님아 일 좀 해라...기본적인 맞춤법은 점검해서 내보내야 하는 거 아니냐고...출판사가 그런 일 하시는 분들 아닌가',
#  '와 미친 뒤로 느껴버리고만 문성씨 너무 야하다',
#  '역시 떡대수가 최고야!!!!',
#  '키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나?  키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나? 키스도 능숙해졌나?   이 음란한 형 누구거야 ',
#  '정말 너무 엄청납니다 제발 더... 더 주세여. .',
#  '허벅지굵기차이에숨을못쉬겠어요',
#  '아미치겠다 누가 일주일만 기절시켜주실분 아아',
#  '아너무좋아너무좋아너무좋아너무좋아너무좋아너무좋아',
#  '아코피나올것같애..\n개좋다진짜\n..',
#  '아..궁금해.. 연하공 능력개쌘공으로 해주세요 그래야 떡대수한테 몸으로 밀려도 능력은 비슷해야 함씩 지켜주는맛?도있구요 ㅋㅋ',
#  '왔다 내 야식',
#  '와이씨미쳤다작가님진짜항상감사하고경이롭고이렇게받기만해도될지항상건강하시고부자되시고사랑하고존경합니다',
#  '와',
#  '호연이 남자네 남자야\n가녀린팔로\n저 허벅지를\n무거워서 어떻게 계속 들고있담?!\n',
#  '진짜이거보려고살아요진심너무행복함 ',
#  '아니근데 너무 거유남문성씨 변화가 갑작스러워서 얼떨떨하네    그렇다고 공을 너무여자같이안만들었으면 씬은 광공이되어야함 ㅋㅋㅋㅋㅋㅋ하 내이변태력 ㅠ ㅠ 실은 문성이 우는거보고싶음ㅎㅎ',
#  '오늘도 공이 예쁘구 수 가슴이 시끄러워요 ♡ ',
#  '알몸보고 개같이 달려왔다',
#  '호연이는 이제 꺼릴 게 없어요! 호연아 보여줘!!!!!!!!',
#  '이번화 너무 짜릿해요 휴',
#  '와 호연이 찢었다... 우리 와기공은 견물도 찢어.... ',
#  '와… 문성씨 뭐에요 ',
#  '호연이 초능력에 문성이 창?! 황금콤비! ',
#  '맞는 것도 이쁘다 우리와기!!!!!',
#  '얘들아......, .., .. 아 재밌다.. 아 재밌다',
#  '영신씨 화려한 셔츠만큼이나 예리한 걸..? 귀엽게 뺨을 붉히는 우리의 호연이가 군필이라니 너무 좋네요. 잠깐이라도 헤어질 걱정없이 진행하면 되겠어..! 둘이 어서 마음의 진도를 쭉쭉 나갔으면',
#  '진짜 아기공 떡대수 맛집이에요 발그레~~',
#  '여기 떡대수 킬러들 다 모인 거 너무 즐겁고 정답고 ',
#  '아기공의 반란이 시작된다',
#  '내가 분명히 우리 호연이 맵다고 했자나 문성아!!',
#  '문성씨 . . 저도 없는게 그렇게(?) 될뻔 했내여 ㅋ. ',
#  '아저씨 누구랑 해보신거예요 자연스럽잖어',
#  '힘내라 키작공....!',
#  '하 진짜 완결 날때까지 대가리 박고 죽고싶다.',
#  '호연이 이쁘구 순하게 생겨가지고는 맨날 먼저 저돌적으로 선키스갈기고, 옷벗기는 손은 또 야무지게 빠른게ㅋㄲㄱㅋㄲ ',
#  '얘네 등치차이 진짜 설렌다 하\n키작미인공을 미남떡대수에 싸서 먹으니 너무맛있네',
#  '가슴이 참 좋다',
#  '하 공이 더 작은 거 뒤지게 좋다.. 한품공 가보자고',
#  '옷 다 입고있는데도 뚫고나오는 육체미…',
#  '끼아아아아아아아아아악 그렇게 들려오면 어뜩햐 질투 폭발해 ♥',
#  '야식이 둘이나... 호연이 좋겠네',
#  'ㅋㅋ 아저씨 어넓골좁인 거 보고 난산하겠다는 생각이나 하고 있는 내가 있음을... 외전으로는 어떠세요 작가님... 알파같지만 오메가인 왕가슴 아저씨와 갓기동정알파연하남 어떠신가요.....제발.........',
#  '순간 회귀물인줄.....다시시작이래서 깔깔',
#  '태석 아저씨 잘생겼네요..?\n호연이가 이 일을 계기로 초능력 각성하게 되는걸까요??!!',
#  '눈물 글썽이는 공이라니...',
#  '마지막맛도리 섭컾수아닐시 죽음뿐',
#  '저 가슴이면 파이즈리 가능할 듯',
#  '와와 나 육성으로 소리지름 진짜 멋있다ㅠㅠㅠㅜㅜㅜㅜㅜㅜ',
#  '너무너무 멋지다...',
#  '진짜 가슴이 뛴다',
#  '맛있어요..',
#  'ㅠㅠㅠ저 늙은이 늙어서 이미 죽은거 아니겠지...??? 그럼 넘 배아프자나... 고통스럽게 죽어야 하는데...',
#  '꿈이라도 좋아',
#  '호연이 진짜 귀엽당....',
#  '키스하고 이렇게 대가리 깨지는 공 처음 봄.... ㅋㅋㅋㅋ',
#  '가슴이 우렁차서 아무것도 안ㄹ려요',
#  'ㅋㅋ 미치겠다 가슴이 너무 커..,,!! 아젖씨 어떻게 가슴으로 그렇게 시끄럽게 할 수가 있어요 제 옆집에서도 고성방가 해주세요 ',
#  'ㅋㅋㅋㅋ댓글들 웃겨 가슴햄버거 먹으면 되겠다니,, 맞는 말씀이세요',
#  '가슴이,,,,',
#  '수 몸매가 아주 쥑여준다 역시 남자는 가슴으로 말해야죠',
#  '냠',
#  '야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 야한데 슬픈데 ',
#  '숨참고봤습니다.........................',
#  '나란히 선 두께차 투샷 생각뿐인 나,,',
#  '상상도 못한 회피방법…',
#  '문성씨....상체 두께 머선일이야 증말',
#  '근데 새삼 작가님 정말그림잘그리신다...흑흑 영원히연재해주세요',
#  '나도...문성씨 같은 남자친구 있었으면....',
#  '무자각 얼빠!',
#  '파란색 곰돌이 후드티 입은 문성씨 사진 구합니다',
#  '문성씨랑 많이 놀러다니자 ㅠㅠㅠㅠ',
#  'ㅅㅂ 데이트 하자는데 등산로 책방ㅋㅋㅋㅋㅋ',
#  '문성씨~~하고와락안는거미쳔나 완전아기자나',
#  '가세요 이사님. 셔츠 찢어버리기 전에 (??)',
#  '새해 기념 문성씨 납치 레츠고',
#  '안돼 우리 애 가만히 두라고',
#  '비누공 떡대수 가보자고',
#  '아닠ㅋㅋㅋㅋㅋㅋㅋ문성씨 인형에 단추 펑 뭐냐구요 ㅋㅋㅋㅋㅋ자까님 진짜 ㅋㅋㅋㅋㅋ',
#  '너무너무 불안해',
#  '문성씨 당신도 토스트케이스 여친이 준거냐고 물어봤었잔아 ㅜ 쌤쌤으로 치자',
#  '여친은 아니고 문짝만한 남친이 있어…\n갓기공 호연 문성씨 반만한 팔뚝으로 박력 넘치는 거 봐',
#  '남친이라고 말해줘',
#  '뭐야 문성 씨 혼자 땅굴 파지 마 지금 분위기 너무 좋거든요??',
#  '나도...좋아...',
#  '끝내준다... 진짜 끝내준다..... 절경이고요 장관입니다.... ',
#  '문성이 부족하면 부족하다고 솔직히 말하지ㅋㅋㅋㅋ',
#  '문성씨... 최고의 수',
#  '와기공 화이팅!!!!!',
#  '저도 작가님을 좋아해요',
#  '신음이 으응 인 공이라니',
#  '진짜 허벅지차이 미친다 ㅋㅋㅋㅋㅋㅋㅋ',
#  '오메 미친…',
#  '문성씨의 두껍고 길쭉한 다리가 진짜...너무 냐해용..........................',
#  '나중에 자유자재로 초능력 사용할수있게되면 들박도 가능한거 아닐지..ㅎㅎ 애기공 가즈아 ',
#  '상탈하고 이리와 진짜 미쳤나',
#  '안정된 이유 31화에 있는거 아님?',
#  '우리 아기공 요리도 잘하네',
#  '이 날만을 기다렸어요',
#  '가슴의 창 너무 기다렸어요 ><',
#  '바뀐 배너부터 아주 훌륭합니다',
#  '지구의 가슴\n돌아와서 기쁘다\n옷이 좀더 레슬링선수같은 일하는복장으로.......헤헷',
#  '와 문성쒸 오드리햅번 있다있어 어쩜 청순한데 지적인데 양아치미 1스푼 문성쒸...♡ 작가님 꼭 10월에 뵈어요 ',
#  '작가님 후기 올라오는날 운명적으로 이 만화를 알게 되어 전체소장을 하게 되다니..아무쪼록 건강 관리 잘 하시고 울 애들 잘 델고 와주세요♡',
#  '10월까지 현생을 버텨야 할 이유가 추가되었다... 호연문성의 뜨거운 컴백.. 기다릴게요',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ진짜!상상도못할ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ딱!키스각이길래 어쩔려나했더니만 거기서ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '작가님 더위조심하시고 미인갓기공쇼 시즌 2 기다리겠습니다',
#  '시즌2 여기서 딱 기다리겠습니다 작가님\n오늘도 일용할 아기공을 주셔서 감사합니다',
#  '고목나무 매미같긴한데 귀엽고 정성스러운 섹스 개좋아유ㅠ 근데ㅜ휴재 하자마자 시즌완결 어흐흪ㄹ듀ㅠㅜㅜㅠ',
#  '미치겠다 별들아 키작공 한줌공 미인공 이 모든 걸 실현시켜주는 작가님.. 당신은 도대체.. 이렇게 제대로 된 키작미인공을 만나뵙게 되어 너무 황송하고 감사할 따름입니다.. 키작미인공 할당제 비엘 웹툰에 당장 실시해라..',
#  '우리 문성씨 시계 좋아보인다 ㅋㅋㅋ 눈길이 가네 테오,일릭이후  맘에 드는 떡대수님 ',
#  '아 ㅁㅊ 너무좋아요 아...아놔 이아저씨가 애생기는것도 아니고? 그런말을. 수가? 어이 이 섹시한 아저씨!!!!!!!!(사랑해.) ',
#  '아니.... 아니.... 아니... 성교육하는것 같네요? 선생님????? 이 문성씨가 미쳤나.... 그러자마자 내일도하고 그다음날도하고 매일매일하자는 남친 캬 연하 남친 잘두셔서 좋으시겠어요.... 호연이 녀석.... 바로 전편에 좋은 남친 되겠다더니 벌써 최고의 남친이 됐는데요',
#  '체격차 최고다...',
#  '진짜 맛도리...',
#  '저 시집못가요',
#  '받는 쾌감을 알게된 문성씨에게 치얼쓰~ ',
#  '어휴 나 떡대수 좋아하네 결제 홀라당 다 했어요ㅋㅋㅋ 전개 빨라서 좋다!! 근데 씬은 좀 길게 부탁을 드리는...',
#  '감사합니다 덕분에 지옥같은 월요일을 버틸 힘이 생겼어요…',
#  '스으상에....미인공의 신쉐계를 넘어서 나에게 한줄기 빛을 준 그대여...더 이상 bl계에 미련이 없사옵니다!!!',
#  '하..레알개좋다미친',
#  '슬근공과!!! 건장근육수의 만남!!!\n',
#  '호연이 미모는 역시 어머님 유전자가!!! 막나가는 연하공 너무 바람직~~~~~',
#  '월요일이 오는게 좋은 이유는 이 웹툰 단 하나입니다',
#  '음란전사군요 문성씨...',
#  '너무 자극적이야 ... ',
#  '아악 진짜 미친 거 아닐까요 문성씨 이렇게 섹시하고 멋지고 잘생기고 다 하면 어떻게 하나요 제 인생은\n너무 쫄리는데 너무 재밌어요 작가님… 매일 일요일 밤이었으면 좋겠어요..',
#  '가터벨트 뭐임?? 나 침흘러',
#  '어떡해ㅠㅠㅠ일케갑자기ㅠㅠㅠㅠ',
#  '아기공아돌아와!!!하지만맛잇다',
#  '케이스를 아련하게 쳐다보더니...버렸다고? 납치된거 아닌가?? ',
#  '아 진짜 꼴려 뒤지겠네~~~ ㅠ',
#  '아 저 상처도 핥아주고 싶다 사랑스러워ㅓ어어어엉',
#  '누가 그렇게 눈뜨래...',
#  '가슴.....아니 라면이 맛있겠어요',
#  '울 와기연하공 덩치는 작아도 완전 불도저다 불도저',
#  '티컵 말티즈랑 근육 빵빵 도베르만이 만나면 이런 모습일까...?',
#  '마 애기책임져라 애기화났잖아',
#  '저기 이미 코 꿰이셨어요',
#  '액정 헐 때까지 읽었네요',
#  '아진짜 미슐랭 쓰리스타를 넘어섰네요.....\n당신한테 보호받는 어린애이고싶지않다는 연하미인키작한줌공 하..ㅋㅋㅋㅋㄱㅋㄱ 작가님 진심으로 감사합니다 사랑해요 ',
#  '하 키작미인공 개좋아하는데 태석씨가 지나치게 맛좋게 생김 하 ㅠㅠㅠㅠㅠㅠㅠ 미안 호연아 그래도 멘공은 너니까 이해해죠..',
#  '당신과 같은 위치에서 의지가 되는 존재가 되고 싶어요... 진ㅁ자 대사 너무 스윗하다 ...ㅜㅅㅜ',
#  '키작공이 세상을 구한다',
#  'ㅎㅎ 담주까지 기다리기 힘드내요. . . . ',
#  '저 연상남이 저를 미치게해요 ',
#  '재탕할 때마다 권문성 개설레고 설호연 개귀엽다',
#  '이집도 저집도 오늘 라면 파티 ㅋㅋ\n이참에 나도 라면  한사발 ㅋ ㅋ\n넘 늦은시간인데 ㅠㅠ\n',
#  '더 주세요.......... 태석씨!!!!! 문성씨!!!!!!!',
#  '어떡해 키작공이 이렇게 맛있는 키워드였다니… 너무 재밌어요ㅠ 작가님 절 책임지세요',
#  '울지마 작은 아기 고앵..☆',
#  '둘이 서있는 투샷 덩치차이도 와꾸합도 하오츠 ㅠㅠㅠ',
#  '꿈내용도 나왔어야..!!!',
#  '태석씨도 예전 동료인가?.. 그럼 그때 문성씨만 산게 아니라 다들 어떻게 잘 살아있는건가?..',
#  '미친....미친.......... 아무렇지도 않게 공대신 총맞아주는 수 어떤데....',
#  '문성씨 개머싯서....',
#  '너무 재밌어서 짧게 느껴짐 개재밌다 1월 1ㅇㄹ부터 행복',
#  '키작공왕가떡대수최고...',
#  '작업복 안에 아무것도 안 입은건가??? 꼬옥 일하다 찢어졌음 좋겟다 ㅎ',
#  '솜씻너 되벌임.. 넣는 거 까지만이라도,,',
#  '미래를 위한 빌드업',
#  '호연이 술버릇이 ... 취하니까 주체 못하고 직진아기연하공되네 기억나면 이불 졸라 찰 듯 ㅋㅋㅋ 근데 권문성은 그걸 또 다 받아줌...ㅠㅠ뽀뽀빼고 읔ㅋ컄ㅋㅋㅋㅠㅠㅠ',
#  '아 울애기 뽀뽀 좀 받아줘요ㅠ 허이잉 이쁘면 다냐ㅠㅠㅠ 바로 능력 갈기네... 진짜 공통점이 하나도 없건만 공에게 이입 대박 잘 됨 넘나 야속한 다정 미남 아저씨ㅠㅠ 유죄야',
#  '????ㅋㅋㅋㅋㅋㅋㅋㅋ아니 이런 키스씬은 처음이네ㅋㅋㅋㅋㅋㅋㅋ 뽀뽀하고 냅다 마빡깨기',
#  'ㅋㅋㅋㅋ아니 ㅋㅋㅋㅋㅋㅋ그렇게 피하기 있냐구요ㅠㅋㅋㅋ',
#  '아니 갑자기 그렇게 통과시키니까 애 이마가 깨지자나요!!!',
#  '어?어??? 분명 달콤한 장면이엇능데 어 ???얼라리?????',
#  '첫 외식(?)인데 술에 취해서 뽀뽀하려다 머리 박고 기절?!?? 안돼!!!!!!!',
#  '오늘도 호연이 미모에 치이고 간다..\n진짜 너무 아름다움',
#  '연하공 질투한다 ㅋㅋㅋ',
#  '식빵토핑으로 문성이 가슴 아아닙니다',
#  '임무할때 입는 옷도 너무 완벽하게 잘어울려!!!',
#  '토스틐ㅋㅋㅋㅋ케이슼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '애기 고양이 가슴에 불을 지르고 도망가다니 책임 지세요.',
#  '엑? 오늘 월요일이고 밤10시인데 업뎃아닌가요?ㅜ',
#  '감사합니다',
#  '담주까지 어떻게 기다리냐... ',
#  '권문성 개여우네 진짜 그러지 마라 너 ... ... ',
#  '아죠씨가 애기 책임져야겟네',
#  '와오 수 피지컬 무슨 일',
#  '점점 더 맛있어지는중',
#  '흥미진진하네요 문성이는 무슨 능력인거죠..?! 생체시계를 돌리려는 연구는 뭐꼬ㅜ 으아아ㅏㅇ 궁금해',
#  '너무... 너무 좋음... 예전에 만난 첫사랑을 만난것도... 저 알파메일이 깔린다는것도... ',
#  '유령의 창이라는 게 수의 창(무기)를 말하는 거였나보네요 캬',
#  '키작공!!!!!!!!!!!!!!!!!! 떡대수!!!!!!!!!!!!!!!!!!!!! 최고!!!!!!!!!!!!!!!!!!!!!!!',
#  '넘 재미있군 흥미진진스',
#  '해시보고 왔어요 좋아좋아',
#  '아니 난닝구만 입으면....',
#  '문성리 날이갈수록 가슴이 커지고있네요...',
#  '비맞은 호연강쥐....',
#  '와  저 능력이  탐나는거  뭐임   ',
#  '뭔가 있는건 아닌거겠죠?\n그럼 넘 슬픈데요ㅠㅠ',
#  '아 마지막 문성씨ㅠㅠ\n진짜 좋다..너무 좋다......어떻게 이런 커플이',
#  '고통이 너무 커서 본인의 기쁨조차 낯선 걸까....',
#  '과묵한 문성씨가 무자각얼빠인 점이 기절쌈바리 포인트...',
#  '하아...이번화 진짜 마음이 충만햐진다...내용적으로도 비주얼적으로도 미친 최고에요ㅠㅠㅠㅠㅠ\n문성씨 옷이랑 머리 바꾸니까 왜케 젊어지냐구~~!!!! 대학생인줄 알겄네 누가 채가겄네~~!!!! 결혼이라는 구속으로 지켜야겠네~~!!!',
#  '어머어머 얘네 사랑한다',
#  '읭 잘보이려고 향수 뿌렸는데 컬처쇼크라니ㅠㅠ우리 이쁜 공이 빡세게 꾸몄는데 안타깝네.. 문성씨한테 많이 알려줘야 할 듯',
#  '등산로라니ㅋㅋㅋㅋㅋㅋㅋㅋ문성씨 나이 꽤 많다는 걸 실감했다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '너무 재밌어요 아♡♡♡',
#  '머리 잘돌아가네 ㅋㅋ',
#  '에공 아기공 문성찌 걱정되서 눈물도 고였어?ㅠㅠㅠ',
#  '귀여운 연하공의 귀감! ㅋㅋㅋㅋ 아저씨라고 부를 때 웃겨서 터짐 ㅋㅋㅋ 말대답 꼬박꼬박 너무 귀여움! ',
#  '아저씨ㅋㅋㅋㅋㅋㅋㅅㅂ',
#  '문성씨의 빛 호연이ㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '당돌 아기공이 저렇게 티를 내니 못 알아챌 수 있나!',
#  '앗 이사님 반응도 궁금하다',
#  '어우 어우 어우 박태석 왜저래 (좋다는 뜻입니다)\n우리 아기남친남편호연이 빨리 애인 단속하자!!!!',
#  '헉!!!',
#  '수가 너무 강해서 재미없을뻔 그 긴장감이 없어져버림 하도 쌔서 그냥 긴장이없어져버렸는데 이번에 존맛이네요 기대가됨!!이렇게 미인공이 본인능력 개안하고 떡대수 구해야 맛잇쯤 ㅋㅋㅋ',
#  '문성씨 짱쎄니까 잘 해결하겟죠??',
#  '남편이라구요',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ콘돔 얘기할 때 호연이 문성 씨 눈이 아니라 가슴을 쳐다보고 있어ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '문성씨 상의탈의 이리와 너무한거 아닌가요 유죄',
#  '설호연놀려먹는문성 존맛.',
#  '아니 문성씨 윗옷 벗으면서 아기공 품는 훈남스킬부터 미쳤음..이번회차 개쩐단 말밖엔',
#  '하....... 문성 씨.......',
#  '연하키작공이 이렇게 맛도리일 줄이야',
#  '수의 너른 가슴에 폭 안긴 갓기공..너무 좋다\n문성씨랑 연결되면서 안정된 건가',
#  '후와아아아아 성큼 다가오는 연하공 미쳤다아아아',
#  '문성이 눈치보는 호연이 너무 귀엽다ㅎㅎㅎ ',
#  '댓글들 정말 넘 웃겨요ㅋㅋㅋ 내마음같아ㅋㅋㅋㅋㅋㅋㅋ 작가님 드디어 오셨군용♡♡♡',
#  '삶의이유가돌아왓다',
#  '행복해서 기절할 거 같애...',
#  '개처럼 달려왔어요 사랑해요 작가님',
#  '자까님진짜 천재세여 제가 문성이보면서 청순고전미남이라생각했는데 어찌 글자고대로 후기에 적혀잇는지 제 생각을 조종하는 엄청난 그림체 엄청난 미인와기공 엄청난 뭐여튼저튼 이것저것 다 엄청난 천재자까님 푹쉬시고 다음시즌에 또 제 머니를 가져가주세요 사랑해요',
#  '전투복 너무 아름다운듯... 그러고보니 호연이가 전투복입은 모습도 보고 싶어요><...이런말하지마까..\n푹쉬시고 돌아오셔서 제 주말을 책임져주세요 기다리겠습니다 작가님 러뷰.',
#  '헣 티엠아이는 언제나 환영합니다!! 온리 떡대수만 보고 달렸는데 키작공 매력에 알아부려써욥 푹 쉬시고 시즌2 기다리겠습니다~~~',
#  '다시 보니까 “아무리 애인이라지만”이라고 말하는 문성 씨... 개좋다',
#  '아기공 진짜 귀하다....... 시즌2만 기다리구 잇것습니다...❤️❤️❤️❤️❤️',
#  '아니 작가님 어떻게 참으셨어요 지금까지 살면서 본 씬들중에 최고입니다.. 덩치 차이 미쳤다',
#  '이런 수를 원했다... 성격도 체격도 ㅠㅠ 무심떡대수의 세상이 도래하리라 찬양하라 믿씁니다아아아',
#  '하 쉬발 애기공ㅜ 열심히박아서 콧잔등에 밴드 떨어진거 어쩌냐',
#  '이번화의 모든 것이 아름답다ㅎㅎ 감사합니다 작가님ㅠㅠ',
#  '작가님 너무 맛있어요.',
#  '체격차 장난아니다...',
#  '극락',
#  '진짜 미쳤다',
#  '내맘도 벅차다',
#  '포메공에 도베르만수 이건.. 된다..!',
#  '아진짜너무감사해요그냥 진짜너무 그냥.. 감사하고.. 행복하세요..',
#  '연하공 남친이되는거고 남편이되는거지 ㅋㅋ\n문성씨 남성용브라나 입에 구속구채우고 가죽팬티입으면 존샥시 할듯\n육체가 유죄야..',
#  '첫컷 보자마자 빤쓰 내렸다...',
#  '와기연하공의 반격(?)이 시작되엇다(?) ㅜㅜㅜㅜㅜㅜ끼야아악 가보자고오오오오옥!!!!!!!!@@@@@@@!!!!!!!',
#  '아기공이네여ㅜㅠ 그렇지 못한 아랫도리지만요ㅋㅋㅋㅋㅋㅋ',
#  '호모나 세상에 이게이뭐람',
#  '와...와......',
#  '아니 와따 마 가슴이 하이고...뭔 동산이 불쑥불쑥 두덩이가 올라와있네 퍼뜩 올라가라 호연아!!!!!!!!!!! ',
#  '핫팬츠야..롱부츠야..?',
#  'ㅇ..아니 뭘 제대로 시작하지도 않았으면서 벌써부터 이러면 어떡해~~~~',
#  '케이스ㅠㅠㅠ버린거라도 걱정되고 납치당한거라도 걱정되는 이 상황',
#  'R U 기만자!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '햐 이맛이지',
#  '문성 씨 나이에 작고 귀여운 연하를 만나면 개꿀인 거라고요ㅠㅠ',
#  '아니 저런 흰색 러닝 입어도 섹시한거 무슨일임',
#  '너무..너무너무 달콤하다 호연아 절대 포기하지마~!!~!!~!!',
#  '더 가까워지기 위함이다..애기야 견디자!!!!',
#  '문성이 너!!!!!!!!!',
#  '이아기가어디서형아꼬시는법을이렇게배워서',
#  '팝콘ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우후후 드뎌 의식하는군...!!!!!!!',
#  '천상의 근육이다!',
#  '문성씨 가슴이 화면밖으로 흘러넘칠거같아서 조마조마...',
#  '호연이 강공이다',
#  '마 끝까지 책임져야지!!!!',
#  '벗고나온걸가.',
#  '월요일만 기다려요 ... ',
#  '이거 된다 붐은 온다',
#  '문성씨 빤스 안입고 나온건가',
#  '아 그래서 대체 언제 섹수하냐구요 답답해죽것네 참말로',
#  '어우 가슴들이 시끄럽네',
#  '환상의 키작공쑈 다음화도 기대합니다',
#  '육체미 대소동... 음란함이 이루말할 수가 없다...',
#  '태석씨가 아리따운 연하공에게 정신 못차리고 휘둘리는거 보고 싶다.... :)',
#  '아저씨 맛있어요 죄송합니다.',
#  '오....공을 괴롭히면 다 죽이겠다는 개짱쎈수....!',
#  '야 우리아가공 기죽이지마!!!',
#  '아조씨 타이밍 무슨 일이야... 눈치 무슨 일이야... 우리 애기갱얼쥐 울잖아요 감상하게 좀 내버려두쇼',
#  '흉통 두께 고자극 오졌다…ㅠㅠㅠ',
#  '구르는 떡대수는 증말 최고다',
#  '제약회사 사장님 그 미중년 비주얼로 그런 짓이나 하고 말이야 어...?',
#  '문성씨 가슴이 너무 시끄러워요',
#  '보다가 너무 놀랐어요ㅋㅋㅋㅋ 머리 꼭 치료받자ㅠ',
#  '앜ㅋㅋㅋㅋㅋ아미친ㅋㅋㅋㅋ앜ㅋㅋㅋㅋ큐ㅠㅠㅠㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋ큐ㅠㅠㅠㅠㅠ',
#  '레전드 어이없는 사고인데 생각보다 심할것같아서 걱정된다... 이마 박살 어떡해',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ아 뽀뽀하고 이 무슨....',
#  '귀여운 나의 회색아기고양이 . . ',
#  '문성이 육체나이 30살인갑네 후... 넘 좋다ㅠㅠ 오늘도 아름다운 문성씨 맘껏 감상했네요. 작가님 오래 연재해주세요ㅠㅠ',
#  '이 아저씨 죄가많네 ',
#  '헐? 나이차가 꽤 나네. 더 꼴린닿ㅎㅎㅎ ',
#  '선다',
#  '엄메 상상하던 거의 과거와 완전 다르네...!!!!',
#  '88올림픽이 최초인줄알았는데',
#  '행복하다... ',
#  '우..우와아악... ',
#  '앗씨 베댓님 진짜 너무 웃겨요ㅠㅠㅠㅋㅋㅋㅋㅋㅋㅋ',
#  '옆집아저씨가 저렇게 멋진데 ㅜㅜ 크윽!!!!!',
#  '최고다…',
#  '너무 맛있고 섹시하고 금욕적이에요',
#  '계속해야만해',
#  '흉부가 기가막혀',
#  '키작미인공에 냉미남떡대수도 모자라 옆집아저씨 역키잡...? 대박 맛도리 조합 아닐수 없다ㅜㅠ작가님천재세요?ㅠㅠㅠ',
#  '뭐야... 역키잡에 시간을 거스르는 자 인가',
#  '뭐야 시간여행자야??',
#  '우와',
#  '하 둘이 너무사랑해서 괴롭다.. 아니 행복해.. ',
#  '그래 이게 구원이고 사랑이고..너무 재밌다 정말',
#  '그래도? 그래도...? 그래도......???? 그래도???? ',
#  '뭐야..문성씨 애기 울리고 꼴린고야...?',
#  '이거지예!!!!!!!!!!!!!!!!!!!!!!! ',
#  '5초컷....아..',
#  '와기 두고 어디가써....',
#  '문성씨 어디갓어ㅠㅠㅠㅠㅠㅠ 이 극강의 회피남....',
#  '미친ㅋㅋㅋㅋㅋㅋㅋ ㅏ 웃으면 안되는데ㅠㅠ',
#  '헤어쥐쥐마',
#  '문성씌…',
#  '어깨 최고...',
#  '등산이 어째서 얼마나 좋은건데 !! 산에 아무도 없으면 응?! 다른것도 할 수 있고!! 얼마나 좋아!!! ㅋㅋㅋㅋ',
#  '나만 문성씨 가슴보는거 아니죠? 대사보다 자꾸 가슴골.......................에.........',
#  '제가 알아요 이거 그 알파 페로몬이라고 하는거예요',
#  '향수까지 뿌리고 독기 가득하게 데이트 빡준비하는 아기공 어떤데 ',
#  '당돌한 아기고양이일세... 잘 하고 있어.',
#  '진짜 왜케 응애같냐 호연이 ㅋㅋㅋ',
#  '이사님 너무 존잘 아닙니까',
#  '호연아 숨 몰아쉬는거진짜너무귀여운거아니니',
#  '으잉?잉?뜬금포?네가 거기서 왜 나와?',
#  '어?뭐야?태석씨의 능력인거야?아니면 빌런인거야?',
#  '젠장.......... 선생님.. 요단강 지나실 때 안되셨나요..? ',
#  '하 아기 귀여워.. ',
#  '왜....... 왜 또 문성 씨만 두고 가........',
#  'ㅠㅠㅠㅠ ㅠㅠㅠ 이번편 너무 불안해요 ㅠㅠㅠ 호연이가 능력으로 문성씨 보호해주길 ㅠㅠ',
#  '호연문성 인형 팔아주심 안되니요 ㅠㅠㅠ',
#  '문성씨는 심각한데 우리 아기공 헤헤 문성씨 보여줘야지 이러고 있음 ㅠ',
#  '땅팔려고 하는 작가님을 혼자 응원합니다 \n전 떡대수 괴롭히는게 재밌어욯ㅎㅎ',
#  '아저씨 제발 죄책감 같은 거 느끼지 마세요. 지금 호연이가 생각하는 거 아저씨가 생각하는 그런 거 아니라구요!!!!!!!',
#  '안돼 생각 멈춰',
#  '호연아!! 여친아니라고 그러면 어떡하니!!',
#  '하진심 호연이얼굴때문에 극락간다진짜 호연아 니얼굴로는 못할게엄ㅅ다사랑한다',
#  '호연아 문저씨 달래줘 ㅜㅜ',
#  'ㅋㅋㅋ아 지금은 얌전하다고 하는거 개웃기네',
#  '호연씨 이건 니가 잘못했다!!!!!!!!!!!',
#  '진자 야하다,,,',
#  '작가님 가방끈이 어디까지인가요',
#  '아~~ 없는게 선다~~~~',
#  '너무좋아서 혼절할것같아요',
#  '한품애기공과 능글으른수....',
#  '들어가는게 ㅈㄴ 야함',
#  '하..보면서 숨을 못 쉬었지만 끝까지 살아남았어요...이제 죽어야겟ㅅ..',
#  '미티겐다',
#  '떡대수 맛집',
#  '은혜롭다...',
#  '꺄아아악 한 편 내내 씬만 나와도 정말 행복해요',
#  '입막고 봤네',
#  '진짜 개.아름답네.. ',
#  '크 키작공 최고',
#  "태석도 안 늙는 거 맞구나 '우리'에게 불로의 피를 심고-라고 했으니까.",
#  '키스해~(짝) 키스해~(짝)',
#  '역시 울 갱얼쥐 능력공이야',
#  '(칼퇴를 해야하는 이유)',
#  '뭘 보신거야..!?궁금해요~',
#  '같이 놀라고 싶다ㅠㅠㅠ',
#  '본격적인 초능력물 …… 너무 좋어요 행복해요',
#  '핫 순식간에 다 읽어버렸다...',
#  '어케 여기서 끊으실 수가',
#  '시즌2 시작했다 넘 조아요',
#  '작가님 덕분에 일요일 밤이 행복해요 ',
#  '반응들을 보니 역시 문성이는 가슴이 본체군요',
#  '왔어!!! 드디어 시작했어!!!',
#  '아니 바뀐 대문 그림 미친 거 아니냐고요 작가님 이렇게 행복하게 만들어주시다니',
#  '하 고전미남수이랑 요즘아이돌같은공 개좋다..갸좋아요 작가님...짱좋아요...',
#  '좋은 남편이 되겠다고 해도 할말없음..',
#  '아 미치겠다\n떡대킬러수 "칼에 찔리는 게 낫겠다" 마음속 발언..',
#  '기다릴게요..(소중)',
#  '미쳣다..한컷 한컷 소듕히 본다는 의미를 알겠ㅅ..ㅓ..츄릅..',
#  '아 미친 개맛있다 진ㄴㄴ짜루',
#  '미인공떡대수너무조아죽고십어여',
#  '박태석 이사 얼굴이 너무 좋아여,,,중년 최고',
#  '너무 기대돼요.. 정말 너무너무 취향 적격인 웹툰.. 꼼짝않고 기다리겠습미다...',
#  '10월까지 기다릴게요 작가님 ㅠ 너무제취향웹툰이에요 손목 건강 잘.지키시구 10월에봬요',
#  '10월까지 버티며 살 이유가 생겼습니다!!! 작가님 더운 여름 몸보양 잘 하시면서 보내세요~~ 기다릴게용♡',
#  '이제 몇달간 월요일을 뭘로 맞이하나',
#  '전투복이 너무 자극적이라 저까지 죽을 것 같아요... 와우...',
#  '시즌2에서 만나요 작가님 뿌앵 ㅠㅠㅠㅠ전 차분한 어른이니까 잘 기다릴 수 있숴요....뿌앵....',
#  ...]
