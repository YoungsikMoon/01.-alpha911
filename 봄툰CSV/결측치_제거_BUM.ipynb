# %%
import pandas as pd

df = pd.read_csv('/content/bomAll_nan포함.csv')
df
# Out:
# <ipython-input-3-a4bfe9384e47>:3: DtypeWarning: Columns (3,4,5,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/bomAll_nan포함.csv')
#        Unnamed: 0        작가명      작가ID 댓글총갯수 댓글총페이지 게시물인덱스  \
# 0             0.0         운석  WofGHOST    20    128    0.0
# 1             1.0         운석  WofGHOST    20    128    1.0
# 2             2.0         운석  WofGHOST    20    128    2.0
# 3             3.0         운석  WofGHOST    20    128    3.0
# 4             4.0         운석  WofGHOST    20    128    4.0
# ...           ...        ...       ...   ...    ...    ...
# 76838     22982.0  samk, 푸죠킹   PAYBACK    20   1685   18.0
# 76839     22983.0  samk, 푸죠킹   PAYBACK    20   1685   19.0
# 76840     22984.0  samk, 푸죠킹   PAYBACK    20   1685    0.0
# 76841     22985.0  samk, 푸죠킹   PAYBACK    20   1685    1.0
# 76842     22986.0  samk, 푸죠킹   PAYBACK    20   1685    2.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76843 entries, 0 to 76842
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  76836 non-null  float64
#  1   작가명         76843 non-null  object
#  2   작가ID        76843 non-null  object
#  3   댓글총갯수       76843 non-null  object
#  4   댓글총페이지      76843 non-null  object
#  5   게시물인덱스      74206 non-null  object
#  6   댓글쓴날짜       74206 non-null  object
#  7   댓글의idx      74205 non-null  object
#  8   작품명         74205 non-null  object
#  9   작품회차        72028 non-null  object
#  10  댓글자명        74198 non-null  object
#  11  댓글          64980 non-null  object
#  12  좋아요횟수       74205 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 7.6+ MB

# %%
df.isnull().sum() # 결측치
# Out:
# Unnamed: 0        7
# 작가명               0
# 작가ID              0
# 댓글총갯수             0
# 댓글총페이지            0
# 게시물인덱스         2637
# 댓글쓴날짜          2637
# 댓글의idx         2638
# 작품명            2638
# 작품회차           4815
# 댓글자명           2645
# 댓글            11863
# 좋아요횟수          2638
# dtype: int64

# %%
df = df.dropna(axis=0) # 결측치 있는 행 제거

# %%
df.isnull().sum() # 결측치
# Out:
# Unnamed: 0    0
# 작가명           0
# 작가ID          0
# 댓글총갯수         0
# 댓글총페이지        0
# 게시물인덱스        0
# 댓글쓴날짜         0
# 댓글의idx        0
# 작품명           0
# 작품회차          0
# 댓글자명          0
# 댓글            0
# 좋아요횟수         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63224 entries, 0 to 76841
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  63224 non-null  float64
#  1   작가명         63224 non-null  object
#  2   작가ID        63224 non-null  object
#  3   댓글총갯수       63224 non-null  object
#  4   댓글총페이지      63224 non-null  object
#  5   게시물인덱스      63224 non-null  object
#  6   댓글쓴날짜       63224 non-null  object
#  7   댓글의idx      63224 non-null  object
#  8   작품명         63224 non-null  object
#  9   작품회차        63224 non-null  object
#  10  댓글자명        63224 non-null  object
#  11  댓글          63224 non-null  object
#  12  좋아요횟수       63224 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 8.8+ MB

# %%
df
# Out:
#        Unnamed: 0        작가명      작가ID 댓글총갯수 댓글총페이지 게시물인덱스  \
# 0             0.0         운석  WofGHOST    20    128    0.0
# 1             1.0         운석  WofGHOST    20    128    1.0
# 2             2.0         운석  WofGHOST    20    128    2.0
# 3             3.0         운석  WofGHOST    20    128    3.0
# 4             4.0         운석  WofGHOST    20    128    4.0
# ...           ...        ...       ...   ...    ...    ...
# 76831     22975.0  samk, 푸죠킹   PAYBACK    20   1685   11.0
# 76832     22976.0  samk, 푸죠킹   PAYBACK    20   1685   12.0
# 76838     22982.0  samk, 푸죠킹   PAYBACK    20   1685   18.0
# 76840     22984.0  samk, 푸죠킹   PAYBACK    20   1685    0.0
# 76841     22985.0  samk, 푸죠킹   PAYBACK    20   1685    1.0
#
#                      댓글쓴날짜     댓글의idx           작품명 작품회차       댓글자명  \
# 0      2022-12-11 22:04:03  1066439.0         유령의 창   9화        그랬댕
# 1      2022-11-16 21:34:26  1037290.0         유령의 창   6화  봄툰러685cef
# ...
